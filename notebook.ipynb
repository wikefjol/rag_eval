# %% [markdown]
# ### **CELL 1: Imports and Paths**
# This cell handles all necessary imports and path configurations for the script.
# It also sets the logging level and displays available LLMs and embeddings for reference.

# %%
# CELL 1: Imports and Paths
import logging
from modules import RAG_tools, models, preprocess
from modules.vectorstore import VectorstoreHandler
from modules.testset_manager import save_test_set
from giskard.rag import KnowledgeBase, generate_testset, evaluate
from modules.giskard_wrappers import GiskardEmbeddingAdapter, GiskardLLMAdapter
from modules.eval_tools import display_evaluation_results
from modules.models import AVAILABLE_EMBS, AVAILABLE_LLMS

# Set logging level to suppress verbose outputs
logging.getLogger().setLevel(logging.WARNING)

# File paths
processed_data_path = "data/processed/processed_data.pkl"  # Preprocessed dataset path
raw_data_path = "data/raw"                                # Raw dataset path
vsts_dir = "data/vectorstores"                            # Vectorstore directory
reports_dir = "eval_results"                              # Directory for evaluation reports

# Define LLM and embedding configurations
# RAG LLM and embedding (used for production RAG)
rag_model_name = "ChatGPT3.5-turbo"
rag_emb_name = "hf-mpnet-base-v2"

# Evaluation LLM and embedding (used for test set generation and evaluation)
kb_model_name = "ChatGPT4o"
kb_emb_name = "openai-embedding-3-large"

# Display available LLMs and embeddings
print(list(AVAILABLE_LLMS.keys()))
print(list(AVAILABLE_EMBS.keys()))
# Out:
# ['ChatGPT4o', 'ChatGPT3.5-turbo', 'Llama3.2-3b']
# ['openai-ada-002', 'openai-embedding-3-small', 'openai-embedding-3-large', 'hf-mpnet-base-v2', 'hf-minilm-l6-v2', 'hf-multiqa-minilm-l6-v1']

# %% [markdown]
# ### **CELL 2: Constructing the RAG**
# In this cell, we:
# 1. Prepare the dataset from raw and processed data paths.
# 2. Initialize the RAG chain components:
#    - The RAG LLM (Language Model).
#    - The RAG embedding.
# 3. Build the Vectorstore and retriever.
# 4. Construct the RAG chain that combines these components for retrieval-augmented generation.

# %%
# CELL 2: Constructing the RAG
# Step 1: Prepare the dataset
data = preprocess.prepare_data(processed_data_path, raw_data_path)

# Step 2: Initialize RAG chain components
rag_llm = models.init_llm(rag_model_name)
rag_embedding = models.init_emb(rag_emb_name)

# Step 3: Initialize and build the VectorstoreHandler
vst_handler = VectorstoreHandler(
    persist_directory=vsts_dir,
    embedding=rag_embedding,
    dataset=data,
    force_rebuild=False  # Set to True to force rebuild of the vectorstore
)

# Build vectorstore and retriever
vst = vst_handler.init_vectorstore()
retriever = vst_handler.init_retriever(vst, k=2)

# Build the RAG chain
chain = RAG_tools.build_rag_chain(retriever, rag_llm)
# Out:
# Loading processed data from data/processed/processed_data.pkl...
# Loading existing vectorstore from data/vectorstores/sentence-transformers_all-mpnet-base-v2/9a7d1387f14cfe05da8b0b963ad3411f6081192c542dc549d032564dca53d52a...

# %% [markdown]
# ### **CELL 3: RAG Chain Demonstration**
# Here, we test the RAG chain to verify it functions as expected.
# We provide a text prompt to the chain and display its response.
# This demonstrates the RAG's ability to retrieve relevant information and generate an output.
#
# We also introcue an answer function, which is a wrapper of the chain (and the handle_query function in the RAG_tools module) that just deals with str input/outputs - needed for the evaluation in the last cell

# %%
# CELL 3: Demonstrating the RAG chain
# Define a prompt for testing
test_prompt = "What are the main topics covered in the dataset?"
response = chain.invoke(test_prompt)  # Invoke the chain with the prompt
print("RAG Response:", response)       # Display the output

# For later, we want to have an answer_fn which just produces the asnwer without any other fluff:
answer_fn = RAG_tools.create_answer_fn(chain)
answer = answer_fn(test_prompt)
print("RAG Answer: ", answer)
# Out:
# RAG Response: {'question': 'What are the main topics covered in the dataset?', 'answer': 'The main topics covered in the dataset appear to be the expected outcomes and impacts of research projects, the assessment of future expected impacts, contributions to challenges at a European/Global level, embedding projects into overarching goals, and demonstrating knowledge of both MSCA and EU strategies.', 'docs': [Document(id='ac83fd47-b916-4c18-b1d2-e96d93d81910', metadata={}, page_content='MSCA-PF-FORMSET ve  1.00 20230406 Page 1 of 20 Las  saved 07/04/2023 07:42'), Document(id='31975363-4f2e-4d19-8c61-7914c05953c7', metadata={}, page_content='MSCA POSTDOCTORAL FELLOWSHIP HANDBOOK 2024\n➢ Fo  each expec ed ou come, p ovide qua ified i dica o s, whe e possible. Fo  example,\nexpec ed  eve ues f om  ew  ech ologies, size of pa ie  g oups  ha  will be affec ed by a\n ew  ea me ,  umbe  of  ew jobs/po e ial p ojec s/ ca ee  oppo u i ies fo   he s aff  ha \nwill be c ea ed af e  a successful p ojec , g ow h i   he  umbe  of use s of eme gi g\n ech ology, e c. ➢ Remai  c edible i   he assessme  of fu u e expec ed impac , a d make i  specific fo  you \np ojec  a d keep i  p opo io a e  o  he ac io . ➢ Mo e examples of expec ed ou comes a d impac  a e p ovided i   he HE P og amme Guide. ➢ Remi d  he evalua o  of  he impo a ce of you   esea ch i  add essi g a challe ge/p io i y a \na Eu opea /Global level. Fo  example, will you   esea ch co ibu e  o:\no UN Sus ai able Developme  Goals\no G ee  Deal, MSCA G ee  Cha e , MSCA-NET Policy B ief o  G ea  Deal\no Ho izo  Eu ope Missio s (Fo  addi io al i fo ma io  feel f ee  o co sul  MSCA-NET\nPolicy B ief o  Missio s i  HE)\n➢ Embed you  p ojec  i o  hose ove a chi g goals – how do  hey co ibu e? A  a ve y small\nscale is pe fec ly fi e. Fo   he SDGs, whe  you fi d  he applicable SDG(s), you ca  i dica e a\nspecific  a ge  i side  he me io ed goal. Fo  defi i g SDGs, feel f ee  o use  he JRC\nK owSDGs Pla fo m 14 which ca  help you  o i eg a e  he SDGs i o  he impac  sec io  of\nyou  p oposal. ➢ Demo s a e  ha  you do  o  o ly k ow abou   he MSCA, bu  abou   eleva  EU s a egies. STRENGTHS FROM THE EVALUATION SUMMARY REPORT\n1. The impac  of  he p oposal beyo d i s immedia e scope is i c eased si ce  he e visaged\n esul s a e highly  eleva  also fo  diffe e  i dus ies, which a e  o  i   he di ec  focus of  he\np oposal. 2. Beyo d  he immedia e scope,  he p oposal will es ablish a lo g- e m collabo a io  be wee \nleadi g labs i  Eu ope a d  he US a d i  will sig ifica ly adva ce  he developme  of mul imodal\nop ical p obes fo  biomedical applica io s. The e is a  excelle  lo g- e m impac   easo ably  o\nbe expec ed.')]}
# RAG Answer:  The main topics covered in the dataset are expected outcomes, future expected impact, contribution to addressing challenges at a European/Global level, alignment with UN Sustainable Development Goals, embedding projects into overarching goals, knowledge of MSCA and EU strategies, collaboration between leading labs in Europe and the US, and the development of multimodal optical probes for biomedical applications.

# %% [markdown]
# ### **CELL 4: Constructing Components for Test Set Generation**
# This cell sets up everything required for generating a test set:
# 1. Initializes the evaluation LLM and embedding (ideally more powerful than the production RAG configuration).
# 2. Wraps these components for compatibility with Giskard.
# 3. Creates a KnowledgeBase object using the dataset, embedding model, and LLM.

# %%
# CELL 4: Constructing Components for Test Set Generation
# Step 1: Initialize KnowledgeBase components
kb_llm = models.init_llm(kb_model_name)
kb_embedding = models.init_emb(kb_emb_name)

# Wrap LLM and embedding for compatibility with Giskard
wrapped_llm = GiskardLLMAdapter(kb_llm)
wrapped_embedding = GiskardEmbeddingAdapter(kb_embedding)

# Step 2: Create the KnowledgeBase
kb = KnowledgeBase(
    data=data,
    embedding_model=wrapped_embedding,
    llm_client=wrapped_llm
)

# %% [markdown]
# ### **CELL 5: Generating the Test Set**
# Using the KnowledgeBase constructed earlier, this cell generates a test set.
# The test set consists of questions in English, with the agent relying solely on the provided context to answer.

# %%
# CELL 5: Generating the Test Set
test_set = generate_testset(
    knowledge_base=kb,
    num_questions=40,
    language='en',
    agent_description=(
        "We're creating a test set for a RAG. The rag will use the context to answer questions from applicants that don't understand the differnt parts of the application process."
        "The agent should only use information from the context and never ask follow up questions."
    )
)
# Out:
# Generating questions: 100%|██████████| 40/40 [02:49<00:00,  4.24s/it]

# %%
test_set_df = test_set.to_pandas()
for index, row in test_set_df.iterrows():
    print(f"Question: {row['question']}")
    print(f"Reference Answer: {row['reference_answer']}")
    print(f"Reference Context: {row['reference_context'][:100]}...")  # Truncate long contexts
    print("Metadata:")
    
    # Iterate through the 'metadata' dictionary and handle nested structures
    if isinstance(row['metadata'], dict):  # Ensure it's a dictionary
        for key, val in row['metadata'].items():
            if isinstance(val, dict):  # Handle nested dictionary
                print(f"  - {key}:")
                for sub_key, sub_val in val.items():
                    print(f"      * {sub_key}: {sub_val}")
            else:
                print(f"  - {key}: {val}")
    else:
        print("  Metadata is not in dictionary format.")
    
    print("")
    print("="*80)
    print("")
# Out:
# Question: What are the language requirements for PPI contract notices in the EU?
# Reference Answer: The PPI contract notices must be published EU-wide in at least English, offers must be accepted and communication with stakeholders must be enabled at all stages in at least English.
# Reference Context: Document 176: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 44
# tex...
# Metadata:
#   - question_type: simple
#   - seed_document_id: 176
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What is the maximum page length for the table describing the capacity of participating organizations in the MSCA Postdoctoral Fellowships 2024 application?
# Reference Answer: For the beneficiary, the table should be maximum 1 page in length; for each associated partner, the table should be maximum ½ page in length.
# Reference Context: Document 126: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 37
# text: Call: HORIZON-...
# Metadata:
#   - question_type: simple
#   - seed_document_id: 126
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What is required for Global Fellowships in the MSCA Postdoctoral Fellowships 2024 application?
# Reference Answer: For Global Fellowships, a letter(s) of commitment from associated partners hosting the outgoing phase is required. The letter must include a heading or stamp from the institution, be up-to-date (not dated prior to the call publication), demonstrate the will to actively participate in the proposal, and explain the precise role. The absence of such a letter will render the proposal inadmissible and it will not be evaluated.
# Reference Context: Document 127: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 38
# text: Call: HORIZON-...
# Metadata:
#   - question_type: simple
#   - seed_document_id: 127
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What are some reasons applicants may be refused under the Horizon 2023-2025 program?
# Reference Answer: Applicants will be refused if they have misrepresented the information required as a condition for participating in the procedure or have failed to supply that information; or were previously involved in the preparation of documents used in the award procedure where this entails a breach of the principle of equality of treatment, including distortion of competition, that cannot be remedied otherwise.
# Reference Context: Document 154: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 22
# tex...
# Metadata:
#   - question_type: simple
#   - seed_document_id: 154
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What are some key transferable skills highlighted for MSCA Postdoctoral Fellowship applicants?
# Reference Answer: Key transferable skills include teaching and mentoring students and doctoral candidates, project/financial/organizational management, development and organization of follow-up projects, acquisition/development of skills in working in an international environment, entrepreneurial skills and competencies, handling intellectual property rights, and training in gender awareness.
# Reference Context: Document 23: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 24
# text: MSCA POSTDOCTORAL FELLOWSHI...
# Metadata:
#   - question_type: simple
#   - seed_document_id: 23
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What measures are being taken to protect European communication networks according to the EU's strategy?
# Reference Answer: The protection of European communication networks involves identifying and assessing cyber threats and security risks for 5G networks, as outlined in the EU Toolbox on 5G cybersecurity. This includes avoiding the participation of high-risk supplier entities in the development of technologies linked to the evolution of European communication networks to prevent technology transfer and dependencies. Additionally, leveraging EU Research & Innovation Funding programmes to develop European capacities in 5G and post-5G technologies is a strategic risk mitigating measure.
# Reference Context: Document 139: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 7
# text...
# Metadata:
#   - question_type: simple
#   - seed_document_id: 139
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What should be included in the work package table and Gantt chart according to the MSCA Postdoctoral Fellowship Handbook 2024?
# Reference Answer: All activities should be included in the work package table and Gantt chart (section 3.1).
# Reference Context: Document 29: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 30
# text: MSCA POSTDOCTORAL FELLOWSHI...
# Metadata:
#   - question_type: simple
#   - seed_document_id: 29
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Considering the evaluation summary reports for MSCA Postdoctoral Fellowship proposals, what is a prevalent weakness related to the originality and innovation potential, especially in terms of recent developments and working hypotheses?
# Reference Answer: A common weakness is that the originality and innovation potential of the proposal is not outlined in a sufficiently convincing and detailed manner, particularly as the background on recent developments in the field of the proposal is not presented in sufficient detail to support the working hypotheses.
# Reference Context: Document 16: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 17
# text: MSCA POSTDOCTORAL FELLOWSHI...
# Metadata:
#   - question_type: complex
#   - seed_document_id: 16
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Under what specific conditions or scenarios does the activity include processing personal data associated with criminal convictions or offenses, according to the ethics issues table in the application document?
# Reference Answer: Yes No
# Reference Context: Document 106: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 17
# text: Applica io  fo...
# Metadata:
#   - question_type: complex
#   - seed_document_id: 106
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Under Horizon Europe, what is the highest funding rate applicable to Research and Innovation actions, considering the specific conditions outlined in the general annexes for the 2023-2025 work programme?
# Reference Answer: 100%
# Reference Context: Document 164: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 32
# tex...
# Metadata:
#   - question_type: complex
#   - seed_document_id: 164
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Could you specify the file name and the page number where the document titled 'Ansökningsmallen med instruktioner' is located, considering it might be Document 90?
# Reference Answer: The file name is 'Ansökningsmallen med instruktioner.pdf' and the page number is 1.
# Reference Context: Document 90: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 1
# text: ...
# Metadata:
#   - question_type: complex
#   - seed_document_id: 90
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What are the specific formatting requirements for the body text of the MSCA-2024-PF proposal, particularly regarding font type and size, and how do these requirements relate to the page limit constraints for sections 1, 2, and 3?
# Reference Answer: The reference font for the body text of proposals is Times New Roman (Windows platforms), Times/Times New Roman (Apple platforms) or Nimbus Roman No. 9 L (Linux distributions). The use of a different font is not advised and is subject to the cumulative conditions that the font is legible and that its use does not significantly shorten the representation of the proposal in number of pages compared to using the reference font.
# Reference Context: Document 115: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 26
# text: Call: HORIZON-...
# Metadata:
#   - question_type: complex
#   - seed_document_id: 115
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: When preparing an application for Horizon Europe funding, which documents are absolutely essential for applicants to thoroughly read, considering that the application must comply with the general conditions and specific criteria outlined in the General Annexes and other related materials?
# Reference Answer: Applicants are invited to read the call documentation on the topic page of the Funding & Tenders Portal, the General Annexes, the Horizon Europe Programme Guide, the EU Funding & Tenders Portal Online Manual, and the EU Grants AGA — Annotated Grant Agreement.
# Reference Context: Document 135: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 3
# text...
# Metadata:
#   - question_type: complex
#   - seed_document_id: 135
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Under what specific call identifier should proposals for the MSCA Postdoctoral Fellowships 2024 be submitted, considering the details in the application form document?
# Reference Answer: HORIZON-MSCA-2024-PF-01
# Reference Context: Document 128: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 39
# text: Call: HORIZON-...
# Metadata:
#   - question_type: complex
#   - seed_document_id: 128
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Could you provide the opening and closing dates for the 2024 MSCA PF Scheme applications, ensuring the information is sourced from the official document titled '240514_MSCA_PF_Info_Day_Overview-1.pdf' on page 10?
# Reference Answer: The opening date is 23/4/2024 and the closing date is 11/9/2024 (5pm CET).
# Reference Context: Document 88: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf
# page_number: 43
# text: 2024 MSCA PF Sc...
# Metadata:
#   - question_type: distracting element
#   - seed_document_id: 88
#   - distracting_context: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf
# page_number: 10
# text: UK Success s a is ics – H2020 a d Ho izo  Eu ope
# Numbe  of MSCA I dividual Fellows
# Thema ic discipli es of successful UK-
# (Ho izo  2020)
# based I dividual Fellows (Ho izo  2020)
# 3000 2558
# CHE
# s
# w 2500 SOC 14%
# o
# lle
# 23% ECO
# F 2000
# d 2%
# e
#  s
# o h 1500 984 1099
# fo
#
# 1000 728 779
# ENG
# e 632 15%
# b 486 508 PHY
# m 253 374
# u 500 177 8%
# N 35
# MAT
# 0
# 3%
# ENV
# 12%
# LIF
# 23%
# Hos i g Cou y
# CHE ECO ENG ENV LIF MAT PHY SOC
# Ho izo  Eu ope Success  a e of MSCA PF p oposals submi ed
# wi h UK i s i u io s
# 2021 MSCA PF Call 14.78%
# 2022 MSCA PF Call 17.74%
# 2023 MSCA PF Call 21.96%
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: For the MSCA Postdoctoral Fellowships 2024, is there a specific page limit for Part B of the application form if the applicant is submitting a proposal in the field of engineering?
# Reference Answer: The page limit for Part B of the application form is 10 pages.
# Reference Context: Document 129: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 40
# text: Call: HORIZON-...
# Metadata:
#   - question_type: distracting element
#   - seed_document_id: 129
#   - distracting_context: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf
# page_number: 10
# text: UK Success s a is ics – H2020 a d Ho izo  Eu ope
# Numbe  of MSCA I dividual Fellows
# Thema ic discipli es of successful UK-
# (Ho izo  2020)
# based I dividual Fellows (Ho izo  2020)
# 3000 2558
# CHE
# s
# w 2500 SOC 14%
# o
# lle
# 23% ECO
# F 2000
# d 2%
# e
#  s
# o h 1500 984 1099
# fo
#
# 1000 728 779
# ENG
# e 632 15%
# b 486 508 PHY
# m 253 374
# u 500 177 8%
# N 35
# MAT
# 0
# 3%
# ENV
# 12%
# LIF
# 23%
# Hos i g Cou y
# CHE ECO ENG ENV LIF MAT PHY SOC
# Ho izo  Eu ope Success  a e of MSCA PF p oposals submi ed
# wi h UK i s i u io s
# 2021 MSCA PF Call 14.78%
# 2022 MSCA PF Call 17.74%
# 2023 MSCA PF Call 21.96%
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Under what conditions must the host organization for the European Fellowship be situated in a specific location, such as a MS / AC / Eu a om AC, according to the application submission guidelines?
# Reference Answer: The host organization for the European Fellowship must be located in a MS / AC / Eu a om AC.
# Reference Context: Document 69: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf
# page_number: 24
# text: Eligibili y C i...
# Metadata:
#   - question_type: distracting element
#   - seed_document_id: 69
#   - distracting_context: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 27
# text: Ho izo  Eu ope - Wo k p og amme 2023-2025
# Ge e al A exes
# E — Docume s
# Submissio
# All p oposals mus  be submi ed elec o ically via  he Fu de s & Te de s Po al elec o ic
# submissio  sys em (accessible via  he  opic page i   he Sea ch Fu di g & Te de s sec io ).
# Pape  submissio s a e NOT possible.
# P oposals mus  be comple e a d co ai  all pa s a d ma da o y a exes a d suppo i g
# docume s.
# The applica io  fo m will have  wo pa s:
# – Pa  A ( o be filled i  di ec ly o li e) co ai s admi is a ive i fo ma io  abou   he
# applica  o ga isa io s (fu u e coo di a o  a d be eficia ies a d affilia ed e i ies),
#  he summa ised budge  fo   he p oposal a d call-specific ques io s;
# – Pa  B ( o be dow loaded f om  he Po al submissio  sys em, comple ed a d  he
# assembled a d  e-uploaded as a PDF i   he sys em) co ai s  he  ech ical desc ip io
# of  he p ojec .
# A exes a d suppo i g docume s will be di ec ly available i   he submissio  sys em a d
# mus  be uploaded as PDF files (o  o he  fo ma s allowed by  he sys em).
# P oposals should be desig ed  o s ay as close as possible  o  he awa d c i e ia (see A ex D
# above). The applica io  fo m will help  o achieve  his.
# Whe  submi i g  he p oposal,  he coo di a o  will have  o co fi m  ha   hey have  he
# ma da e  o ac  fo  all applica s. Mo eove ,  hey will have  o co fi m  ha   he i fo ma io  i
#  he applica io  is co ec  a d comple e a d  ha  all pa icipa s comply wi h  he co di io s fo
#  eceivi g EU fu di g (especially eligibili y, fi a cial a d ope a io al capaci y, exclusio ,
# e c.). P oposals  o  complyi g wi h  hese  equi eme s will be  ejec ed. Befo e sig i g  he
# g a , each pa icipa  will have  o co fi m  his agai  by sig i g a decla a io  of ho ou .
# Fo  lump sum g a s p oposals,  he es ima ed budge  mus  be desc ibed i  a de ailed budge
#  able. This will be used as a basis fo  jus ifyi g a d/o  fixi g  he lump sum amou . As  he
# lump sum mus  be a  app oxima io  of  he cos s ac ually i cu ed,  he cos s i cluded i   his
# de ailed budge   able mus  comply wi h  he basic eligibili y co di io s fo  EU ac ual cos
# g a s (see AGA — A o a ed G a  Ag eeme , A icle 6). This is pa icula ly impo a  fo
# pu chases a d subco ac i g, which mus  e su e bes  value fo  mo ey (o , if app op ia e,  he
# lowes  p ice) a d be f ee f om a y co flic s of i e es . If  he budge   able co ai s i eligible
# cos s,  he g a s may be  educed (eve  la e  o  du i g impleme a io  of  he p ojec  o  af e
#  hey e d). Excep io ally,  he Decisio  au ho isi g  he use of lump sum fu di g fo  a specific
# ac io  migh  specify  ha  a de ailed budge   able is  o   equi ed.
# Applica s may be asked a  a la e  s age fo  fu he  docume s (fo  legal e i y valida io ,
# fi a cial capaci y check, ba k accou  valida io , e c.).
# Page 27 of 45
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Under the Horizon 2023-2024 program rules, what are some specific reasons an applicant might be refused participation if they have failed to demonstrate the necessary skills and experience at both the departmental and institutional level?
# Reference Answer: Applicants will be refused if they have misrepresented the information required as a condition for participating in the procedure or have failed to supply that information; or were previously involved in the preparation of documents used in the award procedure where this entails a breach of the principle of equality of treatment, including distortion of competition, that cannot be remedied otherwise.
# Reference Context: Document 154: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 22
# tex...
# Metadata:
#   - question_type: distracting element
#   - seed_document_id: 154
#   - distracting_context: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf
# page_number: 36
# text: Hos  I s i u io s
# Why a e  hey  he bes  place  o u de ake  he p ojec ?
# Does  he hos  have  he  ecessa y skills a d expe ie ce
#  o help mee   he p ojec  objec ives ( esea ch &  ai i g)?
# Look beyo d  he po e ial supe viso  – depa me al &
# i s i u io al level ma e s as well
# How will you be i eg a ed i o  he i s i u io ?
# The i s i u io   eeds  o be awa e of  he submissio !
# Wo k closely wi h colleagues  o se  expec a io s a d avoid
# su p ises (du i g p oposal developme  a d p ojec
# impleme a io )
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: In the context of the Horizon Europe program, what are the expected outcomes for the execution stage of a PCP/PPI project, particularly if the procurement procedure involves a two-stage submission process?
# Reference Answer: The expected outcome of the execution stage is the implementation of the procurement procedure and of the PCP/PPI contracts. For PCP, this includes validating and comparing the performance of the competing PCP solutions to verify if they can be converted into permanent service. For PPI, this includes deploying the innovative solutions and evaluating the results in real-life operating conditions, with a duration that allows for appropriate evaluation of the potential impact of these solutions if converted into permanent service.
# Reference Context: Document 171: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 39
# tex...
# Metadata:
#   - question_type: distracting element
#   - seed_document_id: 171
#   - distracting_context: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 28
# text: Ho izo  Eu ope - Wo k p og amme 2023-2025
# Ge e al A exes
# F — P ocedu e
# Evalua io  p ocedu e a d  a ki g
# Calls may be subjec   o ei he  a si gle-s age submissio  p ocedu e o  a  wo-s age
# submissio  p ocedu e. The evalua io  p ocedu e may be o ga ised i  o e (s a da d) o
# seve al s eps.
# I   he fi s  s age of a  wo-s age submissio , applica s will be  eques ed  o submi  o ly a
# ou li e applica io  (which will be evalua ed agai s  o ly  wo awa d c i e ia: ‘Excelle ce’ a d
# ‘Impac ’). Successful applica s will be i vi ed  o submi  a full applica io  fo   he seco d
# s age (which will be evalua ed agai s   he full se  of awa d c i e ia).
# P oposals will be checked fo  fo mal  equi eme s (admissibili y a d eligibili y) a d  he
# evalua ed (fo  each  opic sepa a ely) by a  evalua io  commi ee composed of i depe de
# ex e al expe s fo  ope a io al capaci y a d awa d c i e ia (see A exes C a d D above) a d
#  he   a ked acco di g  o  hei  quali y sco e.
# Fo  lump sum g a s p oposals, comme s o   he de ailed lump sum budge   able will be
# p ovided i   he Evalua io  Summa y Repo  o ly fo  p oposals i vi ed  o g a  ag eeme
# p epa a io  (o  placed i   he  ese ve lis ) a d o es  ejec ed (i  pa ) due  o sig ifica
# ove es ima io  o  u de es ima io  of cos s.
# Excep io ally, whe e i dica ed i   he specific call/ opic co di io s,  he evalua io  commi ee
# may be composed pa ially o , i   he case of ‘Coo di a io  a d suppo  ac io s’, pa ially o
# fully of  ep ese a ives of EU i s i u io s.
# Fo  p oposals wi h  he same sco e wi hi  a si gle budge  e velope (wi h  he excep io  of  he
# fi s  s age of  wo-s age submissio s) a me hod  o es ablish  he p io i y o de  will be
# de e mi ed,  aki g i o co side a io   he objec ives of  he specific  opic. I   he abse ce of
# special a a geme s i   he specific call/ opic co di io s,  he followi g me hod will apply:
# Fo  each g oup of p oposals wi h  he same sco e, s a i g wi h  he g oup achievi g  he highes
# sco e a d co i ui g i  desce di g o de :
# 1) P oposals  ha  add ess aspec s of  he call  ha  have  o  o he wise bee  cove ed by
# mo e highly  a ked p oposals will be co side ed  o have  he highes  p io i y.
# 2) The p oposals ide ified u de  1), if a y, will  hemselves be p io i ised acco di g  o
#  he sco es  hey have bee  awa ded fo  ‘Excelle ce’. Whe   hese sco es a e equal,
# p io i y will be based o  sco es fo  ‘Impac ’. I   he case of ‘I ova io  ac io s’,
# p io i y will be give   o  he sco e fo  ‘Impac ’, followed by  ha  fo  ‘Excelle ce’.
# 3) If  ecessa y,  he ge de  bala ce amo g  he  esea che s  amed i   he  esea che s  able
# i   he p oposal, will be used as a fac o  fo  p io i isa io .
# 4) If  ecessa y, a y fu he  p io i isa io  will be based o  geog aphical dive si y, defi ed
# as  he  umbe  of Membe  S a es o  Associa ed Cou ies  ep ese ed i   he p oposal,
# Page 28 of 45
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Could you provide the email contact for the MSCA Postdoctoral Fellowships 2024, specifically for inquiries related to the Green Charter practices in research management?
# Reference Answer: ma iecu ie-uk@uk o.ac.uk
# Reference Context: Document 46: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf
# page_number: 1
# text: Ma ie Skłodowska...
# Metadata:
#   - question_type: distracting element
#   - seed_document_id: 46
#   - distracting_context: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 13
# text: MSCA POSTDOCTORAL FELLOWSHIP HANDBOOK 2024
# Miles o es a e co ol poi s i   he p ojec  helpi g  o cha  p og ess.
# Miles o es may co espo d  o  he achieveme  of a key  esul , allowi g  he
#  ex  phase of  he wo k  o begi . They may also be  eeded a  i e media y
# poi s so  ha , if p oblems have a ise , co ec ive measu es ca  be  ake .
# Miles o e
# A miles o e may be a c i ical decisio  poi  i   he p ojec  whe e, fo
# example,  he co so ium mus  decide which of seve al  ech ologies  o adop
# fo  fu he  developme . The achieveme  of a miles o e should be
# ve ifiable.
# The MSCA G ee  Cha e  is a code of good p ac ice fo  i dividuals a d
# i s i u io s  ha  a e i   eceip  of MSCA fu di g. I  p omo es  he sus ai able
# impleme a io  of  esea ch ac ivi ies. The goal of  he G ee  Cha e  is  o
# e cou age sus ai able  hi ki g i   esea ch ma ageme .
# I   he B2 Sec io  8 you ca  show how you i cluded e vi o me al
# MSCA G ee  Cha e
# co side a io s i   he p oposed p ojec ’s impleme a io .
# Mo e i fo ma io  is available o  h ps://ma ie-sklodowska-cu ie-
# ac io s.ec.eu opa.eu/abou -msca/msca-g ee -cha e  a d i  a
# The Ma ie Skłodowska-Cu ie Ac io s G ee  Cha e  Su vey: G ee i g
# p ac ices i  MSCA p ojec s
# Objec ives a e  he goals of  he wo k pe fo med wi hi   he p ojec , i   e ms
# of i s  esea ch a d i ova io  co e . This will be  a sla ed i o  he
# p ojec ’s  esul s.
# Objec ives
# These may  a ge f om  ackli g specific  esea ch ques io s,
# demo s a i g  he feasibili y of a  i ova io , sha i g k owledge
# amo g s akeholde s o  specific issues. These poi s could be
# co side ed i  each a d eve y p oposal.
# The  a u e of  he objec ives will depe d o   he  ype of ac io , a d  he
# scope of  he  opic.
# Ou comes a e  he expec ed effec s, ove   he medium  e m, of p ojec s
# suppo ed u de  a give   opic. The  esul s of a p ojec  should co ibu e  o
#  hese ou comes, fos e ed i  pa icula  by  he dissemi a io  a d exploi a io
# measu es. This may i clude  he up ake, diffusio , deployme , a d/o  use
# Ou comes of  he p ojec ’s  esul s by di ec   a ge  g oups. Ou comes ge e ally occu
# du i g o  sho ly af e   he e d of  he p ojec .
# Example: 9 Eu opea  ai po s adop   he adva ced fo ecas i g sys em
# demo s a ed du i g  he p ojec .
# Ope  scie ce is a  app oach based o  ope  coope a ive wo k a d
# sys ema ic sha i g of k owledge a d  ools as ea ly a d widely as possible
# i   he p ocess. Ope  scie ce p ac ices i clude ea ly a d ope  sha i g of
#  esea ch (fo  example  h ough p e- egis a io ,  egis e ed  epo s, p e-
# p i s, o  c owd-sou ci g);  esea ch ou pu  ma ageme ; measu es  o
# Ope  Scie ce e su e  ep oducibili y of  esea ch ou pu s; p ovidi g ope  access  o
#  esea ch ou pu s (such as publica io s, da a, sof wa e, models, algo i hms,
# a d wo kflows); pa icipa io  i  ope  pee - eview; a d i volvi g all  eleva
# k owledge ac o s i cludi g ci ize s, civil socie y a d e d use s i   he co-
# c ea io  of R&I age das a d co e s (such as ci ize  scie ce).
# Resea ch ou pu s  efe   o  esul s ge e a ed by  he ac io   o which access
# ca  be give  i   he fo m of scie ific publica io s, da a o  o he  e gi ee ed
# Resea ch ou pu  ou comes a d p ocesses such as sof wa e, algo i hms, p o ocols a d
# elec o ic  o ebooks.
# 12
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: In the context of the MSCA Postdoctoral Fellowships 2024 application form, what are the essential components of open science practices, particularly considering the infrastructure and resources available at the participating organizations?
# Reference Answer: Open science practices include early and open sharing of research (for example through pre-registration, registered reports, pre-prints, or crowd-sourcing); research output management; measures to ensure reproducibility of research outputs; providing open access to research outputs (such as publications, data, software, models, algorithms, and workflows); participation in open peer-review; and involving all relevant knowledge actors including citizens, civil society, and end users in the co-creation of R&I agendas and contents (such as citizen science).
# Reference Context: Document 120: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 31
# text: Call: HORIZON-...
# Metadata:
#   - question_type: distracting element
#   - seed_document_id: 120
#   - distracting_context: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 40
# text: MSCA POSTDOCTORAL FELLOWSHIP HANDBOOK 2024
# ➢ I comi g phase ( e u   o Eu opea  hos ): specify  he measu es pla ed fo   he successful
# ( e)i eg a io  of  he  esea che .
# • Quali y a d capaci y of  he pa icipa i g o ga isa io s, i cludi g i f as uc u e,
# logis ics a d facili ies should be ou li ed i  Pa  B-2 Sec io  5 (“Capaci y of  he
# Pa icipa i g O ga isa io s”).
# ➢ I  sho , explai   ha  you will have access  o  esea ch/ ech ical i f as uc u e (equipme ,
# labs, sof wa e,  ech ology, da a sou ces, access  o e d use s), access  o admi is a ive
# i f as uc u e (s aff  ai i g  esou ces, lib a y use, access  o fi a ce office,  esea ch office o
# you  pe so al wo ki g space e c.)  ha  will assu e smoo h execu io  of you  p ojec .
# ➢ I  is  o   ecessa y  o explai  wha   he i f as uc u e is as you may  o  have space, you ca
#  hough  efe   o B2- Sec io  5 whe e  he e a e fu he  de ails o  i f as uc u e.
# Fo  seco dme  a d  o -academic placeme  hos s:
# ➢ Desc ibe  he  esea ch  eam/e vi o me , explai   he i eg a io  i o  eam/e vi o me ,
#  ha  you will have access  o  esea ch/ ech ical a d admi is a ive i f as uc u e a d a
# dedica ed wo k space.
# No e  ha  fo  GF, bo h  he quali y a d capaci y of  he ou goi g Thi d Cou y hos  a d  he
#  e u  hos  should be ou li ed.
# Associa ed pa e s li ked  o a be eficia y15
# If applicable, ou li e he e  he i volveme  of a y 'associa ed pa e s li ked  o a be eficia y'
# (i  pa icula ,  he  ame of  he e i y,  he  ype of li k wi h  he be eficia y a d  he  asks  o be
# ca ied ou ).
# ➢ If you  hos  o ga isa io  has a  associa ed pa e  li ked  o  hem whe e you will spe d some
# pa  of  he  esea ch (fo  example if you a e a  u ive si y bu  o e of  he  esea ch i f as uc u es
# is available o  associa ed Facul y/ I s i u e) you will  eed  o b iefly desc ibe  he  a u e of  he
# associa io  o  affilia io  a d  he  ole of  his o ga isa io  i  you  fellowship a d  he  esea ch
# p ojec .
# ➢ Explai  wha  pa  of  esea ch will be co duc ed wi hi   his pa e  o ga isa io  a d wha
# i f as uc u e will be used.
# 15 See  he defi i io s sec io  of  he MSCA Wo k P og amme fo  fu he  i fo ma io .
# 39
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Hi, I'm going through the detailed application instructions for the MSCA Postdoctoral Fellowships 2024 and want to confirm, what is the page limit for Part B of the application form?
# Reference Answer: The page limit for Part B of the MSCA Postdoctoral Fellowships 2024 application form is 10 pages.
# Reference Context: Document 129: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 40
# text: Call: HORIZON-...
# Metadata:
#   - question_type: situational
#   - seed_document_id: 129
#   - situational_context: An applicant is carefully reviewing the complex application instructions for the MSCA Postdoctoral Fellowships 2024, ensuring they understand the specific requirements for their research proposal and associated documentation.
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Hi, I'm working on an ethics review form for a proposal involving clinical studies. Could you tell me if the activity involves the use of human embryonic stem cells (hESCs) as outlined in the Ethics Issues Table on page 17 of the document?
# Reference Answer: Yes No
# Reference Context: Document 106: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 17
# text: Applica io  fo...
# Metadata:
#   - question_type: situational
#   - seed_document_id: 106
#   - situational_context: A research assistant preparing an ethics review form carefully considers potential ethical issues regarding human participation and personal data processing in a proposal involving clinical studies.
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: Hello, I'm working on a fellowship application where I aim to tackle misinformation. Could you advise on the recommended number of research work packages for a 2-3 year MSCA Postdoctoral Fellowship project?
# Reference Answer: It is recommended to have no more than 2-3 research work packages.
# Reference Context: Document 35: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 36
# text: MSCA POSTDOCTORAL FELLOWSHI...
# Metadata:
#   - question_type: situational
#   - seed_document_id: 35
#   - situational_context: A researcher seeks to emphasize the societal impact of their proposed project in a fellowship application by detailing plans to combat misinformation through structured work packages and efficient time management.
# ...
#
# ================================================================================
#
# Question: What is the file name and page number mentioned in the context?
# Reference Answer: The file name mentioned in the context is 'Ansökningsmallen med instruktioner.pdf' and the page number referenced is 1.
# Reference Context: Document 90: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 1
# text: ...
# Metadata:
#   - question_type: double
#   - original_questions: [{'question': 'What is the file name mentioned in the context?', 'answer': "The file name mentioned in the context is 'Ansökningsmallen med instruktioner.pdf'."}, {'question': 'What page number is referenced in the context?', 'answer': 'The page number referenced in the context is 1.'}]
#   - seed_document_id: 90
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What information about the supervisor is required in the application form and how can you edit the contact details of the researcher?
# Reference Answer: The application form requires the details of the supervisor, including their name, first name, and e-mail, which are read-only and should be edited in the 'Participants' step of the submission wizard. To edit the contact details of the researcher, you need to go back to the Participant’s page of the submission wizard and save the changes, as the name and e-mail of the researcher are read-only in the administrative form, with only additional details being editable there.
# Reference Context: Document 99: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 10
# text: Applica io  fo ...
# Metadata:
#   - question_type: double
#   - original_questions: [{'question': 'What information about the supervisor is required in the application form?', 'answer': "The application form requires the details of the supervisor, including their name, first name, and e-mail. This information is read-only and should be edited in the 'Participants' step of the submission wizard."}, {'question': 'How can you edit the contact details of the researcher in the application form?', 'answer': 'To edit the contact details of the researcher, you need to go back to the Participant’s page of the submission wizard and save the changes. The name and e-mail of the researcher are read-only in the administrative form, and only additional details can be edited there.'}]
#   - seed_document_id: 99
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What are the criteria for assessing high-risk suppliers of mobile network communication equipment in the Horizon Europe programme, and are entities subject to EU restrictive measures eligible to participate?
# Reference Answer: The assessment of high-risk suppliers is based on criteria such as the likelihood of interference from a non-associated third country, characteristics of the entity’s ownership or governance, the entity’s business conduct, characteristics of the respective third country, and cybersecurity practices throughout the entire supply chain. Entities subject to EU restrictive measures under Article 29 of the Treaty on the European Union (TEU) and Article 215 of the Treaty on the Functioning of the EU (TFEU), as well as Article 75 TFEU, are not eligible to participate in any capacity, including as beneficiaries, affiliated entities, associated partners, third parties giving in-kind contributions, subcontractors, or recipients of financial support to third parties.
# Reference Context: Document 140: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 8
# text...
# Metadata:
#   - question_type: double
#   - original_questions: [{'question': 'What are the criteria for assessing high-risk suppliers of mobile network communication equipment in the Horizon Europe programme?', 'answer': 'The assessment is based on criteria such as the likelihood of interference from a non-associated third country, characteristics of the entity’s ownership or governance, the entity’s business conduct, characteristics of the respective third country, and cybersecurity practices throughout the entire supply chain.'}, {'question': 'Are entities subject to EU restrictive measures eligible to participate in the Horizon Europe programme?', 'answer': 'Entities subject to EU restrictive measures under Article 29 of the Treaty on the European Union (TEU) and Article 215 of the Treaty on the Functioning of the EU (TFEU), as well as Article 75 TFEU, are not eligible to participate in any capacity, including as beneficiaries, affiliated entities, associated partners, third parties giving in-kind contributions, subcontractors, or recipients of financial support to third parties.'}]
#   - seed_document_id: 140
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What is mentioned about this in that document?
# Reference Answer: The Community Research and Development Information Service (CORDIS) is the European Commission’s primary public repository and portal to disseminate information on all EU-funded research projects and their results. It provides information about calls, projects, patents, and contracts related to all European projects financed by Directorate-General Research.
# Reference Context: Document 11: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 12
# text: MSCA POSTDOCTORAL FELLOWSHI...
# Metadata:
#   - question_type: conversational
#   - seed_document_id: 11
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What is it according to this?
# Reference Answer: The individual threshold score for evaluation criteria in full applications is 3.
# Reference Context: Document 158: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 26
# tex...
# Metadata:
#   - question_type: conversational
#   - seed_document_id: 158
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What is the purpose of this?
# Reference Answer: The EU Toolbox on 5G cybersecurity aims to jointly identify and assess cyber threats and security risks for 5G networks, and it recommends adding country-specific information to protect European communication networks. It also emphasizes developing European capacities in 5G and post-5G technologies to mitigate strategic risks and avoid the participation of high-risk supplier entities in technology development.
# Reference Context: Document 139: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
# page_number: 7
# text...
# Metadata:
#   - question_type: conversational
#   - seed_document_id: 139
#   - topic: content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What aspects should be addressed?
# Reference Answer: At a minimum, the following aspects should be addressed: Hosting arrangements, including integration in the team/institution(s) and support services available to the researcher; Quality and capacity of the participating organizations, including infrastructure, logistics, and facilities.
# Reference Context: Document 123: file_name: Ansökningsmallen med instruktioner.pdf
# page_number: 34
# text: Call: HORIZON-...
# Metadata:
#   - question_type: conversational
#   - seed_document_id: 123
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What are some of these?
# Reference Answer: Open science practices include early and open sharing of research (for example through pre-registration, registered reports, pre-prints, or crowd-sourcing); research output management; measures to ensure reproducibility of research outputs; providing open access to research outputs (such as publications, data, software, models, algorithms, and workflows); participation in open peer-review; and involving all relevant knowledge actors including citizens, civil society and end users in the co-creation of R&I agendas and contents (such as citizen science).
# Reference Context: Document 19: file_name: MSCA_PF2024_handbook-1.pdf
# page_number: 20
# text: MSCA POSTDOCTORAL FELLOWSHI...
# Metadata:
#   - question_type: conversational
#   - seed_document_id: 19
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================
#
# Question: What is needed for these entities?
# Reference Answer: A letter of commitment is required for partner organizations in a third country hosting the outgoing phase of a Global Fellowship.
# Reference Context: Document 83: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf
# page_number: 38
# text: Le e s of Commi...
# Metadata:
#   - question_type: conversational
#   - seed_document_id: 83
#   - topic: content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# ================================================================================

# %% [markdown]
# ### **CELL 6: Evaluating the RAG**
# This cell evaluates the RAG chain using the generated test set and KnowledgeBase.
# The evaluation results are displayed to assess the RAG's performance on the test set.

# %%
# CELL 6: Evaluating the RAG Using the Test Set
report = evaluate(answer_fn, testset=test_set, knowledge_base=kb)
display_evaluation_results(report)
# Out:
# Asking questions to the agent: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# CorrectnessMetric evaluation: 100%|██████████| 40/40 [00:53<00:00,  1.34s/it]
# === RAG Evaluation Results ===
#
# Overall Correctness: 12.50%
# Total Test Cases: 40
#
# --- RAG Component Scores ---
# GENERATOR: 14.29%
# RETRIEVER: 14.29%
# REWRITER: 4.76%
# ROUTING: 100.00%
# KNOWLEDGE_BASE: 94.05%
#
# --- Correctness by Question Type ---
# complex: 28.57%
# conversational: 0.00%
# distracting element: 14.29%
# double: 0.00%
# simple: 14.29%
# situational: 14.29%
#
# --- Correctness by Topic ---
# content='"European Research Funding Program"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 1873, 'total_tokens': 1880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0' usage_metadata={'input_tokens': 1873, 'output_tokens': 7, 'total_tokens': 1880, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}: 8.33%
# content='"MSCA Postdoctoral Fellowships 2024"' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 2177, 'total_tokens': 2189, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_703d4ff298', 'finish_reason': 'stop', 'logprobs': None} id='run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0' usage_metadata={'input_tokens': 2177, 'output_tokens': 12, 'total_tokens': 2189, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}: 14.29%
#
# --- Problematic Cases ---
# Question: What are the language requirements for PPI contract notices in the EU?
# Ground Truth: The PPI contract notices must be published EU-wide in at least English, offers must be accepted and communication with stakeholders must be enabled at all stages in at least English.
# Model Response: There is no information provided in the context regarding language requirements for PPI contract notices in the EU.
# Reason: The agent stated that there is no information provided in the context regarding language requirements, but the reference answer provides specific language requirements for PPI contract notices in the EU.
# ----------------------------------------
# Question: What is required for Global Fellowships in the MSCA Postdoctoral Fellowships 2024 application?
# Ground Truth: For Global Fellowships, a letter(s) of commitment from associated partners hosting the outgoing phase is required. The letter must include a heading or stamp from the institution, be up-to-date (not dated prior to the call publication), demonstrate the will to actively participate in the proposal, and explain the precise role. The absence of such a letter will render the proposal inadmissible and it will not be evaluated.
# Model Response: For Global Fellowships in the MSCA Postdoctoral Fellowship 2024 application, applicants need to have at least 2 tables - one for the beneficiary in MS/AC and one for the host organization in associated partner countries. If applicants have an additional non-academic placement at the end of the fellowship, they also need to have 2 tables - one for the beneficiary in MS/AC and one for the non-academic partner in MS/AC. If applicants are applying for a Global Fellowship and have an additional non-academic placement, they need to have 3 tables - one for the beneficiary in MS/AC (1 page), one for the host organization in a third country, and one for the non-academic partner in MS/AC.
# Reason: The agent provided information about tables required for the application, but the reference answer specifies that a letter of commitment from associated partners is required. The agent's answer does not address the key requirement mentioned in the reference answer.
# ----------------------------------------
# Question: What are some reasons applicants may be refused under the Horizon 2023-2025 program?
# Ground Truth: Applicants will be refused if they have misrepresented the information required as a condition for participating in the procedure or have failed to supply that information; or were previously involved in the preparation of documents used in the award procedure where this entails a breach of the principle of equality of treatment, including distortion of competition, that cannot be remedied otherwise.
# Model Response: Applicants may be refused under the Horizon 2023-2025 program if they scored less than 70% on their proposal, or if they were rejected as either ineligible or inadmissible under the 2023 MSCA Postdoctoral Fellowship call.
# Reason: The agent provided reasons related to scoring and eligibility under a specific call, but the reference answer specifies reasons related to misrepresentation of information and breach of equality principles.
# ----------------------------------------
# Question: What are some key transferable skills highlighted for MSCA Postdoctoral Fellowship applicants?
# Ground Truth: Key transferable skills include teaching and mentoring students and doctoral candidates, project/financial/organizational management, development and organization of follow-up projects, acquisition/development of skills in working in an international environment, entrepreneurial skills and competencies, handling intellectual property rights, and training in gender awareness.
# Model Response: Some key transferable skills highlighted for MSCA Postdoctoral Fellowship applicants include project management skills, leadership skills, supervisory skills, interdisciplinary research experience, international research experience, development of new knowledge, acquisition of new technical and transferable skills, and collaboration with various stakeholders in academia and beyond.
# Reason: The agent's answer includes some relevant skills like project management and international research experience, but misses specific skills such as teaching and mentoring, financial management, entrepreneurial skills, and handling intellectual property rights, which are highlighted in the reference answer.
# ----------------------------------------
# Question: What measures are being taken to protect European communication networks according to the EU's strategy?
# Ground Truth: The protection of European communication networks involves identifying and assessing cyber threats and security risks for 5G networks, as outlined in the EU Toolbox on 5G cybersecurity. This includes avoiding the participation of high-risk supplier entities in the development of technologies linked to the evolution of European communication networks to prevent technology transfer and dependencies. Additionally, leveraging EU Research & Innovation Funding programmes to develop European capacities in 5G and post-5G technologies is a strategic risk mitigating measure.
# Model Response: Research and innovation actions (RIA) and innovation actions (IA) that aim to directly produce plans and agreements or designs for new, altered, or improved products, processes, or services are being taken to protect European communication networks according to the EU's strategy. Additionally, addressing EU policy priorities and global challenges through research and innovation is another measure being taken.
# Reason: The agent's answer is too vague and does not specifically address the measures outlined in the EU's strategy, such as identifying and assessing cyber threats, avoiding high-risk suppliers, and leveraging EU Research & Innovation Funding for 5G technologies.
# ----------------------------------------
# Question: What should be included in the work package table and Gantt chart according to the MSCA Postdoctoral Fellowship Handbook 2024?
# Ground Truth: All activities should be included in the work package table and Gantt chart (section 3.1).
# Model Response: The work package table should include the proposed Work Packages (WP), major deliverables, milestones, secondments, placements if applicable. The Gantt chart should show the schedule and indicate the number of months elapsed from the start of the action (Month 1).
# Reason: The agent provided specific details about what should be included in the work package table and Gantt chart, but the reference answer simply states that all activities should be included, according to section 3.1 of the handbook.
# ----------------------------------------
# Question: Considering the evaluation summary reports for MSCA Postdoctoral Fellowship proposals, what is a prevalent weakness related to the originality and innovation potential, especially in terms of recent developments and working hypotheses?
# Ground Truth: A common weakness is that the originality and innovation potential of the proposal is not outlined in a sufficiently convincing and detailed manner, particularly as the background on recent developments in the field of the proposal is not presented in sufficient detail to support the working hypotheses.
# Model Response: The prevalent weakness related to the originality and innovation potential, especially in terms of recent developments and working hypotheses, is that the proposal does not fully consider how the researcher's existing professional experience is relevant to the proposed project.
# Reason: The agent stated that the weakness is related to the researcher's existing professional experience, but should have mentioned the lack of detail in outlining originality and innovation potential, and insufficient background on recent developments.
# ----------------------------------------
# Question: Under what specific conditions or scenarios does the activity include processing personal data associated with criminal convictions or offenses, according to the ethics issues table in the application document?
# Ground Truth: Yes No
# Model Response: The activity includes processing personal data associated with criminal convictions or offenses if it involves information and/or materials subject to national security restrictions.
# Reason: The agent provided a specific condition involving national security restrictions, which does not match the reference answer 'Yes No' that suggests a binary response or a misunderstanding of the question.
# ----------------------------------------
# Question: Could you specify the file name and the page number where the document titled 'Ansökningsmallen med instruktioner' is located, considering it might be Document 90?
# Ground Truth: The file name is 'Ansökningsmallen med instruktioner.pdf' and the page number is 1.
# Model Response: Based on the information provided in the context, it is not possible to specify the file name or the page number of the document 'Ansökningsmallen med instruktioner' as Document 90. The context does not mention any specific details about Document 90 or the location of this specific document within the application forms.
# Reason: The agent stated that it is not possible to specify the file name or the page number, but the reference answer provides specific details: the file name is 'Ansökningsmallen med instruktioner.pdf' and the page number is 1.
# ----------------------------------------
# Question: What are the specific formatting requirements for the body text of the MSCA-2024-PF proposal, particularly regarding font type and size, and how do these requirements relate to the page limit constraints for sections 1, 2, and 3?
# Ground Truth: The reference font for the body text of proposals is Times New Roman (Windows platforms), Times/Times New Roman (Apple platforms) or Nimbus Roman No. 9 L (Linux distributions). The use of a different font is not advised and is subject to the cumulative conditions that the font is legible and that its use does not significantly shorten the representation of the proposal in number of pages compared to using the reference font.
# Model Response: The specific formatting requirements for the body text of the MSCA-2024-PF proposal include using Times New Roman (Windows platforms), Times/Times New Roman (Apple platforms) or Nimbus Roman No. 9 L (Linux distributions) font for the body text. The use of a different font for the body text is not advised. The font size should be legible and should not significantly alter the presentation of the proposal in terms of the number of pages compared to using the specified font. These font requirements relate to the page limit constraints for sections 1, 2, and 3, as all tables, figures, references, and any other elements pertaining to these sections must be included as an integral part of these sections and count towards the page limit. The page limit for these sections is that they should not exceed 10 pages when combined, including all elements within them. Exceeding this page limit may result in automatic warnings and potential removal of excess pages before submission.
# Reason: The agent provided additional information about page limits and formatting requirements that were not included in the reference answer. The reference answer focuses solely on the font type and size requirements without mentioning page limits or consequences of exceeding them.
# ----------------------------------------
# Question: When preparing an application for Horizon Europe funding, which documents are absolutely essential for applicants to thoroughly read, considering that the application must comply with the general conditions and specific criteria outlined in the General Annexes and other related materials?
# Ground Truth: Applicants are invited to read the call documentation on the topic page of the Funding & Tenders Portal, the General Annexes, the Horizon Europe Programme Guide, the EU Funding & Tenders Portal Online Manual, and the EU Grants AGA — Annotated Grant Agreement.
# Model Response: When preparing an application for Horizon Europe funding, applicants must thoroughly read the following essential documents:
# 1. Pos doc o al Fellowships Guide fo Applica s 2024
# 2. MSCA Wo k P og amme 2023 - 2025
# 3. Specific FAQs fo Pos doc o al Fellowships call
# 4. MSCA-NET FAQs
# 5. P oposal empla e a d i s uc io s o how o fill i i
# Reason: The agent provided a list of specific documents related to Postdoctoral Fellowships and MSCA, which are not mentioned in the reference answer. The reference answer includes more general documents such as the General Annexes, Horizon Europe Programme Guide, and EU Grants AGA — Annotated Grant Agreement, which are essential for all applicants.
# ----------------------------------------
# Question: For the MSCA Postdoctoral Fellowships 2024, is there a specific page limit for Part B of the application form if the applicant is submitting a proposal in the field of engineering?
# Ground Truth: The page limit for Part B of the application form is 10 pages.
# Model Response: Yes, for the MSCA Postdoctoral Fellowships 2024, if the applicant is submitting a proposal in the field of engineering, Part B of the application form should have a specific page limit based on the guidelines provided in the context.
# Reason: The agent did not provide the specific page limit of 10 pages for Part B of the application form, as required by the reference answer.
# ----------------------------------------
# Question: Under what conditions must the host organization for the European Fellowship be situated in a specific location, such as a MS / AC / Eu a om AC, according to the application submission guidelines?
# Ground Truth: The host organization for the European Fellowship must be located in a MS / AC / Eu a om AC.
# Model Response: The host organization for the European Fellowship must be situated in a Member State (MS) or Associated Country (AC) of the European Union.
# Reason: The agent stated that the host organization must be situated in a Member State or Associated Country of the European Union, but should have included 'Eu a om AC' as well.
# ----------------------------------------
# Question: Under the Horizon 2023-2024 program rules, what are some specific reasons an applicant might be refused participation if they have failed to demonstrate the necessary skills and experience at both the departmental and institutional level?
# Ground Truth: Applicants will be refused if they have misrepresented the information required as a condition for participating in the procedure or have failed to supply that information; or were previously involved in the preparation of documents used in the award procedure where this entails a breach of the principle of equality of treatment, including distortion of competition, that cannot be remedied otherwise.
# Model Response: Applicants might be refused participation if they fail to demonstrate specific measures to enhance career perspectives and employability both inside and outside academia. Additionally, if they do not show expected contributions of proposed skill development to their future career, they may also be refused participation.
# Reason: The agent provided reasons related to career perspectives and employability, but the reference answer specifies refusal reasons related to misrepresentation of information and involvement in document preparation that breaches equality of treatment.
# ----------------------------------------
# Question: In the context of the Horizon Europe program, what are the expected outcomes for the execution stage of a PCP/PPI project, particularly if the procurement procedure involves a two-stage submission process?
# Ground Truth: The expected outcome of the execution stage is the implementation of the procurement procedure and of the PCP/PPI contracts. For PCP, this includes validating and comparing the performance of the competing PCP solutions to verify if they can be converted into permanent service. For PPI, this includes deploying the innovative solutions and evaluating the results in real-life operating conditions, with a duration that allows for appropriate evaluation of the potential impact of these solutions if converted into permanent service.
# Model Response: In the context of the Horizon Europe program, the expected outcomes for the execution stage of a PCP/PPI project, particularly if the procurement procedure involves a two-stage submission process, include assessing the results achieved by each bidder in the previous phase, giving a demonstration to the granting authority of the tested solutions resulting from the PCP, and ensuring that the procurement procedures are open to bidders from EU Member States and countries with which the EU has agreements in the field of public procurement under the conditions laid down in those agreements. Additionally, if the specific call conditions require limited participation for security reasons, participation in the PCP/PPI procedure must also be restricted to bidders meeting this condition.
# Reason: The agent's answer focuses on procedural aspects and eligibility criteria, but does not address the expected outcomes related to the implementation, validation, and evaluation of solutions as described in the reference answer.
# ----------------------------------------
# Question: Could you provide the email contact for the MSCA Postdoctoral Fellowships 2024, specifically for inquiries related to the Green Charter practices in research management?
# Ground Truth: ma iecu ie-uk@uk o.ac.uk
# Model Response: The email contact for inquiries related to the Green Charter practices in research management for the MSCA Postdoctoral Fellowships 2024 would need to be obtained from the MSCA-NET Policy Briefs or from relevant resources provided by the organization. The context does not explicitly mention an email contact for such inquiries.
# Reason: The agent did not provide the specific email contact 'ma iecu ie-uk@uk o.ac.uk' for inquiries related to the Green Charter practices in research management for the MSCA Postdoctoral Fellowships 2024.
# ----------------------------------------
# Question: In the context of the MSCA Postdoctoral Fellowships 2024 application form, what are the essential components of open science practices, particularly considering the infrastructure and resources available at the participating organizations?
# Ground Truth: Open science practices include early and open sharing of research (for example through pre-registration, registered reports, pre-prints, or crowd-sourcing); research output management; measures to ensure reproducibility of research outputs; providing open access to research outputs (such as publications, data, software, models, algorithms, and workflows); participation in open peer-review; and involving all relevant knowledge actors including citizens, civil society, and end users in the co-creation of R&I agendas and contents (such as citizen science).
# Model Response: The essential components of open science practices in the context of the MSCA Postdoctoral Fellowships 2024 application form include specifying the quality and capacity of the host institution for the proposed work, possessing established competencies in areas related to the proposal, having all necessary infrastructure and suitable facilities to implement the proposal, and being prepared to provide all needed administrative support.
# Reason: The agent focused on the infrastructure and resources of the host institution, but should have addressed specific open science practices such as early and open sharing of research, open access, and involving relevant knowledge actors.
# ----------------------------------------
# Question: Hi, I'm working on an ethics review form for a proposal involving clinical studies. Could you tell me if the activity involves the use of human embryonic stem cells (hESCs) as outlined in the Ethics Issues Table on page 17 of the document?
# Ground Truth: Yes No
# Model Response: Yes, the activity involving clinical studies may involve the use of human embryonic stem cells (hESCs) as indicated in the Ethics Issues Table on page 17 of the document.
# Reason: The agent provided a definitive 'Yes' answer, but the reference answer suggests that the correct response should be 'Yes No', indicating uncertainty or a need for further clarification.
# ----------------------------------------
# Question: Hello, I'm working on a fellowship application where I aim to tackle misinformation. Could you advise on the recommended number of research work packages for a 2-3 year MSCA Postdoctoral Fellowship project?
# Ground Truth: It is recommended to have no more than 2-3 research work packages.
# Model Response: For a MSCA Postdoctoral Fellowship project, it is recommended to have a detailed work plan for the non-academic placement, which must be mentioned in the Grant chart and covered in the research work packages. Additionally, the MSCA Work Programme lists mandatory deliverables for Postdoctoral Fellowships that need to be submitted in projects selected for funding. It is important to include mechanisms to assess and mitigate risks, including scientific and non-scientific risks. The Ga aa must be included and should indicate the proposed Work Packages, major deliverables, milestones, secondments, placements, if applicable, and should not exceed the 10-page limit. The schedule in the Ga aa should indicate the number of months elapsed from the start of the action (Month 1). Adjust the number of research work packages according to the activities proposed in the Work Packages.
# Reason: The agent provided a detailed explanation about the structure and requirements of the MSCA Postdoctoral Fellowship project but did not directly answer the user's question about the recommended number of research work packages, which should be 2-3.
# ----------------------------------------
# Question: Hello, as I'm preparing my proposal for the MSCA Postdoctoral Fellowship, could you tell me what is required for Global Fellowships according to the application form?
# Ground Truth: For Global Fellowships, a letter(s) of commitment from associated partners hosting the outgoing phase is required.
# Model Response: For Global Fellowships, you need to allocate Intellectual Property between the two hosts. If applicable, you should describe how the results may be applicable in the long-term. Additionally, you need at least 2 tables-one for the beneficiary in MS/AC and one for the host organization in the associated country. If you have an additional non-academic placement at the end of the fellowship, you also need 2 tables-one for the beneficiary in MS/AC and one for the non-academic partner in MS/AC. If you have a non-academic placement and are applying for a Global Fellowship, you need to have 3 tables-one for the beneficiary in MS/AC and one for the host organization in a third country, and one for the non-academic partner in MS/AC. If you have secondment in your proposal, an additional ½ page table needs to be added for the secondment host organization(s).
# Reason: The agent provided detailed information about the allocation of Intellectual Property and table requirements, but did not mention the requirement for a letter(s) of commitment from associated partners hosting the outgoing phase, which is the key requirement according to the reference answer.
# ----------------------------------------
# Question: Hi there, as I'm preparing my application for the MSCA Postdoctoral Fellowship, I'm curious to know what strengths are typically highlighted in the evaluation summary reports. Could you provide some insights?
# Ground Truth: The proposal presents convincingly the researcher's record, which includes publications in high impact-factor journals, a demonstrated capacity to attract funding, experience in supervising and mentoring activities, prizes and awards. This record renders the researcher's professional growth during the fellowship highly credible. The researcher has already shown independence of thinking and very good potential to secure the proposal execution and to further reach professional maturity. The researcher's CV is very competitive, with high quality and impact publications, international mobility, and a multitude of relevant transferable skills. The professional experience and competences of the researcher are highly appropriate for the proposal. The institution has experience in hosting international researchers and the host group will be an excellent environment for the researcher. The expertise of the main supervisor, of the host research group, and of the supervisor at the secondment institution is soundly documented, and is a very good match with the research proposed. The planned non-academic placement is well described and its value for the project is very convincingly demonstrated, enabling the researcher to gain experience beyond academia and acquire new competences relevant to their profile, especially through the training of teachers.
# Model Response: Some strengths typically highlighted in the evaluation summary reports for the MSCA Postdoctoral Fellowship include the quality and capacity of the host institution for the proposed work, the researcher's competencies and facilities available for the research, the supervision provided, the scientific plan provided in the proposal, the acquisition of new knowledge, the training provided, especially in scientific and soft skills, the personal development opportunities, the experience and track record of the supervisor, the knowledge exchange between the researcher and the host institution, and the three-way knowledge exchange between the researcher, outgoing, and incoming hosts. These are just a few examples of strengths that may be highlighted in the evaluation summary reports.
# Reason: The agent provided a general list of strengths typically highlighted in evaluation reports, but did not specifically address the detailed strengths mentioned in the reference answer, such as the researcher's record, independence, and the specific environment and expertise of the host institution.
# ----------------------------------------
# Question: Hello, I'm a first-time applicant and I'm trying to edit the contact details in the "Participants" step of the submission wizard. Can you tell me what information is read-only in the administrative form for researchers and how this affects the submission process?
# Ground Truth: The name and e-mail of the Researcher and Supervisor are read-only in the administrative form.
# Model Response: The information regarding the legal entity and the academic country in Table 5.1 of the administrative form for researchers is read-only. This means that applicants cannot modify this information, as it is provided for administrative and legal purposes. This information being read-only does not directly affect the submission process, but it is important to ensure that the information is accurate and up to date to comply with administrative and legal requirements.
# Reason: The agent stated that the legal entity and academic country are read-only, but should have said that the name and e-mail of the Researcher and Supervisor are read-only.
# ----------------------------------------
# Question: Hi, I'm reviewing the MSCA Postdoctoral Fellowship Handbook 2024 and I'm quite anxious about my proposal. Could you tell me what happens if my proposal exceeds the page limit?
# Ground Truth: If a proposal exceeds the specified page limit before the deadline, you will receive an automatic warning and will be advised to shorten and re-upload the proposal. After the deadline, excess pages in over-long proposals will be automatically made invisible and therefore will not be taken into consideration by the experts.
# Model Response: If your proposal exceeds the page limit, only the last submitted version of the proposal will be evaluated. It is important to comply with all requested requirements and submit your proposal as early as possible to avoid any issues with the page limit.
# Reason: The agent incorrectly stated that only the last submitted version of the proposal will be evaluated if it exceeds the page limit. The correct procedure is that excess pages will be made invisible after the deadline and not considered by the experts.
# ----------------------------------------
# Question: What is the minimum eligibility criteria for consortium composition in the EU program 2023-2025, and are affiliated entities required to sign the grant agreement?
# Ground Truth: The minimum eligibility criteria for consortium composition require at least three independent legal entities established in different countries: one must be established in a Member State, and two other independent legal entities must be established in different Member States or Associated Countries. Affiliated entities do not sign the grant agreement and do not count towards the minimum eligibility criteria for consortium composition.
# Model Response: The minimum eligibility criteria for consortium composition in the EU program 2023-2025 is that projects must comply with EU policies and priorities. Affiliated entities may be required to sign the grant agreement.
# Reason: The agent provided incorrect information about the minimum eligibility criteria and the role of affiliated entities. The agent did not mention the requirement of three independent legal entities from different countries and incorrectly stated that affiliated entities may be required to sign the grant agreement.
# ----------------------------------------
# Question: What is the flat-rate percentage for indirect costs and how is the pre-financing payment amount determined in the Horizon 2023-2025 program?
# Ground Truth: The flat-rate percentage for indirect costs is 25% of the total eligible direct costs, excluding eligible direct costs for subcontracting, financial support to third parties, and any unit costs or lump sums which include indirect costs. The pre-financing payment is normally 160% of the average EU funding per reporting period, which is the maximum grant amount divided by the number of periods; for actions with only one reporting period, it will be less, as 100% would mean the totality of the grant amount.
# Model Response: The flat-rate percentage for indirect costs is 25% of the total eligible direct costs. The pre-financing payment amount is normally set at 160% of the average EU funding per reporting period, with exceptions allowing for less pre-financing in certain cases.
# Reason: The agent's answer is incomplete. It correctly states the flat-rate percentage for indirect costs as 25% of the total eligible direct costs, but it omits the exclusions mentioned in the reference answer. Additionally, the explanation of the pre-financing payment amount lacks the detail about the calculation for actions with only one reporting period.
# ----------------------------------------
# Question: What is the purpose of the MSC Actions Doctoral Networks and how does the COFUND MSCA aim to engage the public with research?
# Ground Truth: The MSC Actions Doctoral Networks support doctoral programmes developed by various institutions and businesses across Europe and beyond, while the COFUND MSCA aims to bring research closer to the public, increase awareness of research activities, and boost the recognition of science and research education.
# Model Response: The purpose of the MSC Actions Doctoral Networks is to establish long-term collaboration between leading labs in Europe and the US to advance the development of multimodal optical probes for biomedical applications. The COFUND MSCA aims to engage the public with research by promoting the impact of the proposal beyond its immediate scope, highlighting its relevance to various industries, and emphasizing long-term collaboration and advancements in research.
# Reason: The agent provided an incorrect purpose for the MSC Actions Doctoral Networks and COFUND MSCA. The agent mentioned collaboration between labs and promoting impact, but should have mentioned supporting doctoral programmes and bringing research closer to the public.
# ----------------------------------------
# Question: What is the file name and page number mentioned in the context?
# Ground Truth: The file name mentioned in the context is 'Ansökningsmallen med instruktioner.pdf' and the page number referenced is 1.
# Model Response: The file name mentioned in the context is not provided. The page numbers mentioned in the context are pages 4 and 17 of a 45-page document.
# Reason: The agent stated that the file name is not provided and mentioned pages 4 and 17, but should have stated the file name as 'Ansökningsmallen med instruktioner.pdf' and the page number as 1.
# ----------------------------------------
# Question: What information about the supervisor is required in the application form and how can you edit the contact details of the researcher?
# Ground Truth: The application form requires the details of the supervisor, including their name, first name, and e-mail, which are read-only and should be edited in the 'Participants' step of the submission wizard. To edit the contact details of the researcher, you need to go back to the Participant’s page of the submission wizard and save the changes, as the name and e-mail of the researcher are read-only in the administrative form, with only additional details being editable there.
# Model Response: The application form requires information about the general description, role, and profile of the supervisor. To edit the contact details of the researcher, the applicants must make sure that their proposals comply with the layout and remove any pages with unnecessary information before submitting.
# Reason: The agent provided incorrect information about the supervisor's details required in the application form and did not explain how to edit the contact details of the researcher as specified in the reference answer.
# ----------------------------------------
# Question: What are the criteria for assessing high-risk suppliers of mobile network communication equipment in the Horizon Europe programme, and are entities subject to EU restrictive measures eligible to participate?
# Ground Truth: The assessment of high-risk suppliers is based on criteria such as the likelihood of interference from a non-associated third country, characteristics of the entity’s ownership or governance, the entity’s business conduct, characteristics of the respective third country, and cybersecurity practices throughout the entire supply chain. Entities subject to EU restrictive measures under Article 29 of the Treaty on the European Union (TEU) and Article 215 of the Treaty on the Functioning of the EU (TFEU), as well as Article 75 TFEU, are not eligible to participate in any capacity, including as beneficiaries, affiliated entities, associated partners, third parties giving in-kind contributions, subcontractors, or recipients of financial support to third parties.
# Model Response: The criteria for assessing high-risk suppliers of mobile network communication equipment in the Horizon Europe programme include the likelihood of interference from a non-associated third country based on factors such as the ownership or governance structure of the entity and its business conduct. Entities subject to EU restrictive measures are not eligible to participate as beneficiaries, affiliates, or associated parties.
# Reason: The agent provided a partial answer regarding the criteria for assessing high-risk suppliers, omitting details about characteristics of the respective third country and cybersecurity practices. Additionally, the agent did not specify the legal articles under which entities subject to EU restrictive measures are ineligible.
# ----------------------------------------
# Question: What is mentioned about this in that document?
# Ground Truth: The Community Research and Development Information Service (CORDIS) is the European Commission’s primary public repository and portal to disseminate information on all EU-funded research projects and their results. It provides information about calls, projects, patents, and contracts related to all European projects financed by Directorate-General Research.
# Model Response: This document is not an official document published by the European Commission and should not be considered as binding. It is a substitute for official documents such as the MSCA Work Programme 2023-2025, Guide for Applicants for Postdoctoral Fellowship 2024, and official FAQs prepared by the Research Executive Agency (REA).
# Reason: The agent did not provide information about the role of CORDIS as described in the MSCA Postdoctoral Fellowship Handbook 2024. Instead, it gave a disclaimer about the document's official status, which does not answer the user's question.
# ----------------------------------------
# Question: What is it according to this?
# Ground Truth: The individual threshold score for evaluation criteria in full applications is 3.
# Model Response: The threshold is expected to be set at 8 to 8.5.
# Reason: The agent stated that the threshold is expected to be set at 8 to 8.5, but should have said it is 3.
# ----------------------------------------
# Question: What is the purpose of this?
# Ground Truth: The EU Toolbox on 5G cybersecurity aims to jointly identify and assess cyber threats and security risks for 5G networks, and it recommends adding country-specific information to protect European communication networks. It also emphasizes developing European capacities in 5G and post-5G technologies to mitigate strategic risks and avoid the participation of high-risk supplier entities in technology development.
# Model Response: The purpose of this is to outline the roles and responsibilities of participating organizations and individuals in a project proposal. It also includes details about research, technology development, collaboration, and commitment to the project.
# Reason: The agent provided a generic answer about project proposals, which is incorrect. The correct answer should have been about the EU Toolbox on 5G cybersecurity's aim to assess cyber threats and security risks for 5G networks and develop European capacities in 5G technologies.
# ----------------------------------------
# Question: What aspects should be addressed?
# Ground Truth: At a minimum, the following aspects should be addressed: Hosting arrangements, including integration in the team/institution(s) and support services available to the researcher; Quality and capacity of the participating organizations, including infrastructure, logistics, and facilities.
# Model Response: The aspects that should be addressed include the role of participation in the organization in the project, project management, communication, dissemination, engagement, provision of research and technology, co-definition of research and market needs, civil society representation, policy-making or regulation, research performance, technology development, testing/validation of approaches and ideas, prototyping and demonstration, IPR management, ethics information, and additional ethics information.
# Reason: The agent provided a list of general aspects related to project participation and management, but did not specifically address hosting arrangements and the quality and capacity of participating organizations as required by the reference answer.
# ----------------------------------------
# Question: What are some of these?
# Ground Truth: Open science practices include early and open sharing of research (for example through pre-registration, registered reports, pre-prints, or crowd-sourcing); research output management; measures to ensure reproducibility of research outputs; providing open access to research outputs (such as publications, data, software, models, algorithms, and workflows); participation in open peer-review; and involving all relevant knowledge actors including citizens, civil society and end users in the co-creation of R&I agendas and contents (such as citizen science).
# Model Response: Some of the identified risks and emergency plans related to methods and data collection were well considered in the proposal. Additionally, efforts assigned to work packages, including the timing and duration of different work packages, were appropriate and credible within the research work. The allocation of tasks and resources was also considered appropriate in the proposal.
# Reason: The agent provided information about risks, emergency plans, and work packages, which is unrelated to the open science practices mentioned in the reference answer.
# ----------------------------------------
# Question: What is needed for these entities?
# Ground Truth: A letter of commitment is required for partner organizations in a third country hosting the outgoing phase of a Global Fellowship.
# Model Response: Outcomes of the project's results by direct target groups.
# Reason: The agent's answer about outcomes of the project's results does not address the requirement for host organizations, which is a letter of commitment.
# ----------------------------------------
#
# Report saved at: eval_results/unknown_llm_unknown_embedding_20250112_234646

# %% [markdown]
# ## Set up a stronger rag to compare:

# %%
strong_model_name = "ChatGPT4o"
strong_emb_name = "openai-embedding-3-large"

strong_llm = models.init_llm(strong_model_name)
strong_embedding = models.init_emb(strong_emb_name)

# Step 3: Initialize and build the VectorstoreHandler
strong_vst_handler = VectorstoreHandler(
    persist_directory=vsts_dir,
    embedding=rag_embedding,
    dataset=data,
    force_rebuild=False  # Set to True to force rebuild of the vectorstore
)

# Build vectorstore and retriever
strong_vst = strong_vst_handler.init_vectorstore()
strong_retriever = strong_vst_handler.init_retriever(vst, k = 5)

# Build the RAG chain
strong_chain = RAG_tools.build_rag_chain(strong_retriever, strong_llm)
strong_answer_fn = RAG_tools.create_answer_fn(strong_chain)
# Out:
# Loading existing vectorstore from data/vectorstores/sentence-transformers_all-mpnet-base-v2/9a7d1387f14cfe05da8b0b963ad3411f6081192c542dc549d032564dca53d52a...

# %% [markdown]
# Evaluate strong rag,
# keeping the test_set and knowledge base the same

# %%
strong_report = evaluate(strong_answer_fn, testset=test_set, knowledge_base=kb)
# Out:
# Asking questions to the agent: 100%|██████████| 40/40 [02:14<00:00,  3.36s/it]
# CorrectnessMetric evaluation: 100%|██████████| 40/40 [01:00<00:00,  1.52s/it]

# %%
print("Weak rag:")
print(report.component_scores())
print()

print("Strong rag:")
print(strong_report.component_scores())
print()
# Out:
# Weak rag:
#                    score
# RAG Components
# GENERATOR       0.142857
# RETRIEVER       0.142857
# REWRITER        0.047619
# ROUTING         1.000000
# KNOWLEDGE_BASE  0.940476
#
# Strong rag:
#                    score
# RAG Components
# GENERATOR       0.290476
# RETRIEVER       0.357143
# REWRITER        0.198413
# ROUTING         1.000000
# KNOWLEDGE_BASE  0.880952

# %%
df1=report.correctness_by_topic()
df2=strong_report.correctness_by_topic()

for column in df1.columns:
    if column in df2.columns:  # Ensure the column exists in both DataFrames
        print(f"Correctness by topic: {column}")
        print(f"{'Original rag':<20} {'Strong rag':<20}")
        for val1, val2 in zip(df1[column], df2[column]):  # Iterate through the values
            print(f"{str(val1):<20} {str(val2):<20}")  # Adjust column width as needed
        print("=" * 40)  # Separator for clarity
    else:
        print(f"Column '{column}' is missing in one of the DataFrames!")


df1=report.correctness_by_question_type()
df2=strong_report.correctness_by_question_type()

for column in df1.columns:
    if column in df2.columns:  # Ensure the column exists in both DataFrames
        print(f"Correctness by question type: {column}")
        print(f"{'Original rag':<20} {'Strong rag':<20}")
        for val1, val2 in zip(df1[column], df2[column]):  # Iterate through the values
            print(f"{str(val1):<20} {str(val2):<20}")  # Adjust column width as needed
        print("=" * 40)  # Separator for clarity
    else:
        print(f"Column '{column}' is missing in one of the DataFrames!")

report.to_html("notebook_reports/report.html")
strong_report.to_html("notebook_reports/strong_report.html")
# Out:
# Correctness by topic: correctness
# Original rag         Strong rag
# 0.08333333333333333  0.16666666666666666
# 0.14285714285714285  0.2857142857142857
# ========================================
# Correctness by question type: correctness
# Original rag         Strong rag
# 0.2857142857142857   0.42857142857142855
# 0.0                  0.0
# 0.14285714285714285  0.42857142857142855
# 0.0                  0.16666666666666666
# 0.14285714285714285  0.2857142857142857
# 0.14285714285714285  0.14285714285714285
# ========================================

# %%
df1 = report.failures
df2 = strong_report.failures

import textwrap

# Set a character limit for line wrapping
LINE_WIDTH = 80

def wrapped_print(label, text, indent=2):
    wrapped_text = textwrap.fill(text, width=LINE_WIDTH, subsequent_indent=" " * indent)
    print(f"{label}{wrapped_text}")

for idx, row1 in df1.iterrows():
    # Access the id from the current row in df1
    id1 = row1['question']  # Assuming 'question' is the unique identifier

    # Find the corresponding row in df2 using the same id
    row2 = df2[df2['question'] == id1]
    
    if not row2.empty:  # Ensure that a matching row was found
        row2 = row2.iloc[0]  # Get the first matching row as a Series (if there's only one match)

        print("=" * 80)
        wrapped_print("Question: ", id1)
        print()

        # Weak RAG Output
        print("Weak RAG:")
        wrapped_print("  Answer: ", row1['agent_answer'])
        wrapped_print("  Judgment: ", str(row1['correctness']))
        wrapped_print("  Argument: ", row1['correctness_reason'])
        print()

        # Strong RAG Output
        print("Strong RAG:")
        wrapped_print("  Answer: ", row2['agent_answer'])
        wrapped_print("  Judgment: ", str(row2['correctness']))
        wrapped_print("  Argument: ", row2['correctness_reason'])
        print()

        # Reference Answer and Context
        wrapped_print("Reference Answer: ", row1['reference_answer'])
        print()
        wrapped_print("Reference Context: ", row1['reference_context'][:500])  # Truncate context for brevity
        print()
        wrapped_print("Metadata: ", str(row1['metadata']))
        print("=" * 80)
        print()
    else:
        wrapped_print("No matching row in df2 for question: ", id1)
# Out:
# ================================================================================
# Question: What are the language requirements for PPI contract notices in the EU?
#
# Weak RAG:
#   Answer: There is no information provided in the context regarding language requirements
#   for PPI contract notices in the EU.
#   Judgment: False
#   Argument: The agent stated that there is no information provided in the context regarding
#   language requirements, but the reference answer provides specific language
#   requirements for PPI contract notices in the EU.
#
# Strong RAG:
#   Answer: The context provided does not include information about the language
#   requirements for PPI contract notices in the EU.
#   Judgment: False
#   Argument: The agent stated that the context does not include information about the
#   language requirements, but it should have provided the information that PPI
#   contract notices must be published EU-wide in at least English, and offers and
#   communication must be enabled in at least English.
#
# Reference Answer: The PPI contract notices must be published EU-wide in at least English, offers
#   must be accepted and communication with stakeholders must be enabled at all
#   stages in at least English.
#
# Reference Context: Document 176: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 44 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   P epa a io  a d publica io  of  he ope  ma ke  co sul a io  a d call fo   e de
#   U less  he PPI is u de ake  as a follow-up  o a  FP7, Ho izo  2020 o  Ho izo
#   Eu ope PCP53, o  u less  he si ua io  is a low-value PPI below  a io al p ocu
#   eme   h esholds,  he followi g obliga io s apply: – To p epa e  he call fo   e
#   de s, a  ope  ma ke  co s
#
# Metadata: {'question_type': 'simple', 'seed_document_id': 176, 'topic':
#   'content=\'"European Research Funding Program"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 7, \'prompt_tokens\': 1873, \'total_tokens\': 1880,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0\'
#   usage_metadata={\'input_tokens\': 1873, \'output_tokens\': 7,
#   \'total_tokens\': 1880, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What is required for Global Fellowships in the MSCA Postdoctoral Fellowships
#   2024 application?
#
# Weak RAG:
#   Answer: For Global Fellowships in the MSCA Postdoctoral Fellowship 2024 application,
#   applicants need to have at least 2 tables - one for the beneficiary in MS/AC
#   and one for the host organization in associated partner countries. If
#   applicants have an additional non-academic placement at the end of the
#   fellowship, they also need to have 2 tables - one for the beneficiary in MS/AC
#   and one for the non-academic partner in MS/AC. If applicants are applying for
#   a Global Fellowship and have an additional non-academic placement, they need
#   to have 3 tables - one for the beneficiary in MS/AC (1 page), one for the host
#   organization in a third country, and one for the non-academic partner in
#   MS/AC.
#   Judgment: False
#   Argument: The agent provided information about tables required for the application, but
#   the reference answer specifies that a letter of commitment from associated
#   partners is required. The agent's answer does not address the key requirement
#   mentioned in the reference answer.
#
# Strong RAG:
#   Answer: Applicants for Global Fellowships in the MSCA Postdoctoral Fellowships 2024 must
#   fulfill the following requirements:  1. They need at least two tables: one for
#   the beneficiary in an MS/AC and another one for the host organization
#   (associated partner) in a third country. If there is an additional non-
#   academic placement at the end of the fellowship, a total of three tables are
#   needed.  2. Researchers must not have resided or carried out their main
#   activities in the country of the host organization for the outgoing phase for
#   more than 12 months in the 36 months immediately before the call deadline.  3.
#   The researcher must possess a doctoral degree or have successfully defended
#   their doctoral thesis unconditionally before the call deadline.  4. The
#   researcher must be a national or long-term resident of a European Member State
#   (MS) or HE Associated Country (AC).  5. The researcher must have a maximum of
#   8 years of full-time equivalent research experience from the date of award of
#   the first doctoral degree, with certain periods such as maternity leave and
#   long-term sick leave being deductible from this calculation.  6. A designated
#   supervisor who is employed in a host organization must be contacted and
#   secured for agreement to be the supervisor in the project.  7. Applicants who
#   scored over 70% in the previous year's submission (2023) can resubmit,
#   provided they meet all other eligibility criteria. Resubmissions must be
#   indicated in Part A of the current proposal, including the previously
#   submitted proposal reference number.  8. Compliance with the internal
#   requirements of the host organization and any potential internal support they
#   can provide for proposal preparation.  9. The supervisor will contribute
#   actively to the preparation and submission of the proposal, and offer advice
#   and guidance.
#   Judgment: False
#   Argument: The agent provided a detailed list of general requirements for the Global
#   Fellowships in the MSCA Postdoctoral Fellowships 2024, but did not mention the
#   specific requirement of a letter of commitment from associated partners
#   hosting the outgoing phase, which is crucial according to the reference
#   answer.
#
# Reference Answer: For Global Fellowships, a letter(s) of commitment from associated partners
#   hosting the outgoing phase is required. The letter must include a heading or
#   stamp from the institution, be up-to-date (not dated prior to the call
#   publication), demonstrate the will to actively participate in the proposal,
#   and explain the precise role. The absence of such a letter will render the
#   proposal inadmissible and it will not be evaluated.
#
# Reference Context: Document 127: file_name: Ansökningsmallen med instruktioner.pdf page_number: 38
#   text: Call: HORIZON-MSCA-2024-PF-01: MSCA Pos doc o al Fellowships 2024 EU G a
#   s: Applica io  fo m (HE MSCA PF): V3.1 – 28.03.2024 7. Addi io al i fo ma io
#   o  secu i y sc ee i g Addi io al i fo ma io  o  secu i y aspec s  ha  could  o
#   be i cluded i  Pa  A of  he p oposal (if  eeded). 8. E vi o me al co side a io
#   s i  ligh  of  he MSCA G ee  Cha e  Please explai  how  he p oposed p ojec
#   would s ive  o adhe e  o  he
#
# Metadata: {'question_type': 'simple', 'seed_document_id': 127, 'topic': 'content=\'"MSCA
#   Postdoctoral Fellowships 2024"\' additional_kwargs={\'refusal\': None}
#   response_metadata={\'token_usage\': {\'completion_tokens\': 12,
#   \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What are some reasons applicants may be refused under the Horizon 2023-2025
#   program?
#
# Weak RAG:
#   Answer: Applicants may be refused under the Horizon 2023-2025 program if they scored
#   less than 70% on their proposal, or if they were rejected as either ineligible
#   or inadmissible under the 2023 MSCA Postdoctoral Fellowship call.
#   Judgment: False
#   Argument: The agent provided reasons related to scoring and eligibility under a specific
#   call, but the reference answer specifies reasons related to misrepresentation
#   of information and breach of equality principles.
#
# Strong RAG:
#   Answer: Applicants may be refused under the Horizon 2023-2025 program if their proposal
#   involves the same beneficiary and researcher submitted to the previous year's
#   call (2023) and received a score of less than 70%. Additionally, proposals may
#   be rejected if the applicants do not meet all the eligibility criteria.
#   Judgment: False
#   Argument: The agent provided reasons related to proposal scores and eligibility criteria,
#   but the reference answer specifies reasons related to misrepresentation of
#   information and involvement in document preparation that breaches equality of
#   treatment.
#
# Reference Answer: Applicants will be refused if they have misrepresented the information required
#   as a condition for participating in the procedure or have failed to supply
#   that information; or were previously involved in the preparation of documents
#   used in the award procedure where this entails a breach of the principle of
#   equality of treatment, including distortion of competition, that cannot be
#   remedied otherwise.
#
# Reference Context: Document 154: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 22 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   − ba k up cy, wi di g up, affai s admi is e ed by  he cou s, a a geme  wi h c
#   edi o s, suspe ded busi ess ac ivi ies o  o he  simila  p ocedu es (i cludi g
#   p ocedu es fo  pe so s wi h u limi ed liabili y fo   he applica ’s deb s); −
#   hey a e i  b each of social secu i y o   ax obliga io s (i cludi g if do e by
#   pe so s wi h u limi ed liabi
#
# Metadata: {'question_type': 'simple', 'seed_document_id': 154, 'topic':
#   'content=\'"European Research Funding Program"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 7, \'prompt_tokens\': 1873, \'total_tokens\': 1880,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0\'
#   usage_metadata={\'input_tokens\': 1873, \'output_tokens\': 7,
#   \'total_tokens\': 1880, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# No matching row in df2 for question: What are some key transferable skills highlighted for MSCA Postdoctoral
#   Fellowship applicants?
# ================================================================================
# Question: What measures are being taken to protect European communication networks
#   according to the EU's strategy?
#
# Weak RAG:
#   Answer: Research and innovation actions (RIA) and innovation actions (IA) that aim to
#   directly produce plans and agreements or designs for new, altered, or improved
#   products, processes, or services are being taken to protect European
#   communication networks according to the EU's strategy. Additionally,
#   addressing EU policy priorities and global challenges through research and
#   innovation is another measure being taken.
#   Judgment: False
#   Argument: The agent's answer is too vague and does not specifically address the measures
#   outlined in the EU's strategy, such as identifying and assessing cyber
#   threats, avoiding high-risk suppliers, and leveraging EU Research & Innovation
#   Funding for 5G technologies.
#
# Strong RAG:
#   Answer: The context provided does not include specific measures for protecting European
#   communication networks according to the EU's strategy. The details given
#   primarily focus on eligibility, ethical considerations, and security protocols
#   related to EU projects, classified information, and funding mechanisms within
#   the Horizon Europe programme.
#   Judgment: False
#   Argument: The agent did not provide any specific measures for protecting European
#   communication networks according to the EU's strategy, whereas the reference
#   answer outlines specific actions such as identifying cyber threats, avoiding
#   high-risk suppliers, and leveraging EU funding for technology development.
#
# Reference Answer: The protection of European communication networks involves identifying and
#   assessing cyber threats and security risks for 5G networks, as outlined in the
#   EU Toolbox on 5G cybersecurity. This includes avoiding the participation of
#   high-risk supplier entities in the development of technologies linked to the
#   evolution of European communication networks to prevent technology transfer
#   and dependencies. Additionally, leveraging EU Research & Innovation Funding
#   programmes to develop European capacities in 5G and post-5G technologies is a
#   strategic risk mitigating measure.
#
# Reference Context: Document 139: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 7 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   be wee  Chi a a d  he EU o   he Joi  Roadmap fo   he fu u e of EU-Chi a coope
#   a io  i  scie ce,  ech ology, a d i ova io  Res ic io s fo   he p o ec io  of
#   Eu opea  commu ica io   e wo ks — The p o ec io  of Eu opea  commu ica io   e
#   wo ks has bee  ide ified as a  impo a  secu i y i e es  of  he U io  a d i s
#   Membe  S a es.10 I  li e wi h
#
# Metadata: {'question_type': 'simple', 'seed_document_id': 139, 'topic':
#   'content=\'"European Research Funding Program"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 7, \'prompt_tokens\': 1873, \'total_tokens\': 1880,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0\'
#   usage_metadata={\'input_tokens\': 1873, \'output_tokens\': 7,
#   \'total_tokens\': 1880, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What should be included in the work package table and Gantt chart according to
#   the MSCA Postdoctoral Fellowship Handbook 2024?
#
# Weak RAG:
#   Answer: The work package table should include the proposed Work Packages (WP), major
#   deliverables, milestones, secondments, placements if applicable. The Gantt
#   chart should show the schedule and indicate the number of months elapsed from
#   the start of the action (Month 1).
#   Judgment: False
#   Argument: The agent provided specific details about what should be included in the work
#   package table and Gantt chart, but the reference answer simply states that all
#   activities should be included, according to section 3.1 of the handbook.
#
# Strong RAG:
#   Answer: According to the MSCA Postdoctoral Fellowship Handbook 2024, the work package
#   table and Gantt chart should include the following:  1. Proposed Work Packages
#   (WP): Outline the major deliverables, milestones, secondments, and placements
#   if applicable in the Gantt chart.   2. Schedule: Provide the number of months
#   elapsed from the start of the action (Month 1) in the Gantt chart.  3.
#   Specific Requirements:    - Mobility declaration submitted within 20 days of
#   the start of the research training activities and updated via the Funding &
#   Tenders Portal if needed.    - Career development plan of the recruited
#   researcher submitted at the beginning of the action and updated as needed
#   throughout the project.    - Evaluation questionnaires completed by the
#   researcher at the end of the research training activity and a follow-up
#   questionnaire submitted two years later.    - Data management plan submitted
#   within the first 6 months of the project.    - Plan for dissemination and
#   exploitation of results submitted towards the end of the project and kept as a
#   living document.  4. Mentioning Secondments: If secondments are in the
#   proposal, an additional ½ page table should be added for the secondment host
#   organization(s).  5. Mechanisms for Risk Assessment and Mitigation: Include
#   both scientific and non-scientific risks, their likelihood (low, medium,
#   high), and link them with relevant WPs.  6. Contingency Plans: Address
#   potential risks and corresponding alternative strategies to mitigate them.
#   The Gantt chart contributes towards the 10-page limit of the proposal
#   documentation.
#   Judgment: False
#   Argument: The agent provided a detailed list of what should be included in the work
#   package table and Gantt chart, but the reference answer simply states that all
#   activities should be included. The agent's answer is more detailed than
#   necessary and does not directly match the reference answer.
#
# Reference Answer: All activities should be included in the work package table and Gantt chart
#   (section 3.1).
#
# Reference Context: Document 29: file_name: MSCA_PF2024_handbook-1.pdf page_number: 30 text: MSCA
#   POSTDOCTORAL FELLOWSHIP HANDBOOK 2024 ➢ All  he ac ivi ies should be i cluded
#   i   he wo k package  able & Ga  cha  (sec io  3.1). ➢ Summa ise each dissemi a
#   io  ac ivi y wi h specific &  ealis ic de ails, usi g a  able. Fo  example: Ac
#   ivi y Ta ge  audie ce Whe  Whe e Key i dica o s (KPI) Co fe e ce Lis   he  a
#   ge  Es ima ed mo h If k ow  a   he Numbe  of (p ovide  he full audie ce  ha
#   will of p ojec  whe  i   ime of
#
# Metadata: {'question_type': 'simple', 'seed_document_id': 29, 'topic': 'content=\'"MSCA
#   Postdoctoral Fellowships 2024"\' additional_kwargs={\'refusal\': None}
#   response_metadata={\'token_usage\': {\'completion_tokens\': 12,
#   \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: Considering the evaluation summary reports for MSCA Postdoctoral Fellowship
#   proposals, what is a prevalent weakness related to the originality and
#   innovation potential, especially in terms of recent developments and working
#   hypotheses?
#
# Weak RAG:
#   Answer: The prevalent weakness related to the originality and innovation potential,
#   especially in terms of recent developments and working hypotheses, is that the
#   proposal does not fully consider how the researcher's existing professional
#   experience is relevant to the proposed project.
#   Judgment: False
#   Argument: The agent stated that the weakness is related to the researcher's existing
#   professional experience, but should have mentioned the lack of detail in
#   outlining originality and innovation potential, and insufficient background on
#   recent developments.
#
# Strong RAG:
#   Answer: The provided context does not mention a specific prevalent weakness related to
#   the originality and innovation potential concerning recent developments and
#   working hypotheses. Therefore, it does not address this aspect directly.
#   Judgment: False
#   Argument: The agent stated that the context does not mention a specific prevalent
#   weakness, but the reference answer provides a specific weakness related to the
#   lack of detail in outlining originality and innovation potential.
#
# Reference Answer: A common weakness is that the originality and innovation potential of the
#   proposal is not outlined in a sufficiently convincing and detailed manner,
#   particularly as the background on recent developments in the field of the
#   proposal is not presented in sufficient detail to support the working
#   hypotheses.
#
# Reference Context: Document 16: file_name: MSCA_PF2024_handbook-1.pdf page_number: 17 text: MSCA
#   POSTDOCTORAL FELLOWSHIP HANDBOOK 2024 5. The s a e-of- he-a  is ve y well ou
#   li ed:  he  esea ch will b i g  ew pe spec ives a d  ovel k owledge  o i s
#   field of s udy. WEAKNESSES FROM THE EVALUATION SUMMARY REPORTS 1. The o igi
#   ali y a d i ova io  po e ial of  he p oposal is  o  ou li ed i  a sufficie ly
#   co vi ci g a d de ailed ma e , pa icula ly as  he backg ou d o   ece
#   developme s i   he field of  he p oposal is  o
#
# Metadata: {'question_type': 'complex', 'seed_document_id': 16, 'topic': 'content=\'"MSCA
#   Postdoctoral Fellowships 2024"\' additional_kwargs={\'refusal\': None}
#   response_metadata={\'token_usage\': {\'completion_tokens\': 12,
#   \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: Under what specific conditions or scenarios does the activity include processing
#   personal data associated with criminal convictions or offenses, according to
#   the ethics issues table in the application document?
#
# Weak RAG:
#   Answer: The activity includes processing personal data associated with criminal
#   convictions or offenses if it involves information and/or materials subject to
#   national security restrictions.
#   Judgment: False
#   Argument: The agent provided a specific condition involving national security
#   restrictions, which does not match the reference answer 'Yes No' that suggests
#   a binary response or a misunderstanding of the question.
#
# Strong RAG:
#   Answer: The context provided does not contain information regarding the processing of
#   personal data associated with criminal convictions or offenses in relation to
#   the ethics issues table in the application document.
#   Judgment: False
#   Argument: The agent stated that the context does not contain information regarding the
#   processing of personal data associated with criminal convictions or offenses,
#   but the reference answer indicates a simple 'Yes No' response, suggesting the
#   agent did not address the question correctly.
#
# Reference Answer: Yes No
#
# Reference Context: Document 106: file_name: Ansökningsmallen med instruktioner.pdf page_number: 17
#   text: Applica io  fo ms P oposal ID Ac o ym 4 - E hics & secu i y E hics
#   Issues Table 1. Huma  Emb yo ic S em Cells a d Huma  Emb yos Page Does  his ac
#   ivi y i volve Huma  Emb yo ic S em Cells (hESCs)? Yes No Does  his ac ivi y i
#   volve  he use of huma  emb yos? Yes No 2. Huma s Page Does  his ac ivi y i
#   volve huma  pa icipa s? Yes No Does  his ac ivi y i volve i e ve io s
#   (physical also i cludi g imagi g  ech ology,
#
# Metadata: {'question_type': 'complex', 'seed_document_id': 106, 'topic': 'content=\'"MSCA
#   Postdoctoral Fellowships 2024"\' additional_kwargs={\'refusal\': None}
#   response_metadata={\'token_usage\': {\'completion_tokens\': 12,
#   \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: Could you specify the file name and the page number where the document titled
#   'Ansökningsmallen med instruktioner' is located, considering it might be
#   Document 90?
#
# Weak RAG:
#   Answer: Based on the information provided in the context, it is not possible to specify
#   the file name or the page number of the document 'Ansökningsmallen med
#   instruktioner' as Document 90. The context does not mention any specific
#   details about Document 90 or the location of this specific document within the
#   application forms.
#   Judgment: False
#   Argument: The agent stated that it is not possible to specify the file name or the page
#   number, but the reference answer provides specific details: the file name is
#   'Ansökningsmallen med instruktioner.pdf' and the page number is 1.
#
# Strong RAG:
#   Answer: The context provided does not contain information about a document titled
#   'Ansökningsmallen med instruktioner' or its location in terms of file name or
#   page number.
#   Judgment: False
#   Argument: The agent stated that the context does not contain information about the
#   document, but the reference answer provides specific details about the file
#   name and page number.
#
# Reference Answer: The file name is 'Ansökningsmallen med instruktioner.pdf' and the page number is
#   1.
#
# Reference Context: Document 90: file_name: Ansökningsmallen med instruktioner.pdf page_number: 1
#   text:
#
# Metadata: {'question_type': 'complex', 'seed_document_id': 90, 'topic': 'content=\'"MSCA
#   Postdoctoral Fellowships 2024"\' additional_kwargs={\'refusal\': None}
#   response_metadata={\'token_usage\': {\'completion_tokens\': 12,
#   \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# No matching row in df2 for question: What are the specific formatting requirements for the body text of the
#   MSCA-2024-PF proposal, particularly regarding font type and size, and how do
#   these requirements relate to the page limit constraints for sections 1, 2, and
#   3?
# ================================================================================
# Question: When preparing an application for Horizon Europe funding, which documents are
#   absolutely essential for applicants to thoroughly read, considering that the
#   application must comply with the general conditions and specific criteria
#   outlined in the General Annexes and other related materials?
#
# Weak RAG:
#   Answer: When preparing an application for Horizon Europe funding, applicants must
#   thoroughly read the following essential documents:  1. Pos doc o al
#   Fellowships Guide fo Applica s 2024 2. MSCA Wo k P og amme 2023 - 2025 3.
#   Specific FAQs fo Pos doc o al Fellowships call 4. MSCA-NET FAQs 5. P oposal
#   empla e a d i s uc io s o how o fill i i
#   Judgment: False
#   Argument: The agent provided a list of specific documents related to Postdoctoral
#   Fellowships and MSCA, which are not mentioned in the reference answer. The
#   reference answer includes more general documents such as the General Annexes,
#   Horizon Europe Programme Guide, and EU Grants AGA — Annotated Grant Agreement,
#   which are essential for all applicants.
#
# Strong RAG:
#   Answer: When preparing an application for Horizon Europe funding, the absolutely
#   essential documents for applicants to thoroughly read are:  - Postdoctoral
#   Fellowships Guide for Applicants 2024 - MSCA Work Programme 2023 - 2025 -
#   Specific FAQs for Postdoctoral Fellowships call - MSCA-NET FAQs - Proposal
#   template and instructions on how to fill it in
#   Judgment: False
#   Argument: The agent provided a list of specific documents related to Postdoctoral
#   Fellowships, which may not be relevant to all Horizon Europe applications. The
#   reference answer includes general documents applicable to all applicants, such
#   as the General Annexes and the Horizon Europe Programme Guide.
#
# Reference Answer: Applicants are invited to read the call documentation on the topic page of the
#   Funding & Tenders Portal, the General Annexes, the Horizon Europe Programme
#   Guide, the EU Funding & Tenders Portal Online Manual, and the EU Grants AGA —
#   Annotated Grant Agreement.
#
# Reference Context: Document 135: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 3 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   INTRODUCTION These Ge e al A exes se  ou   he ge e al co di io s applicable  o
#   calls a d  opics fo  g a s a d o he  fo ms of fu di g u de   he Ho izo  Eu ope
#   mai  wo k p og amme. They also desc ibe  he evalua io  a d awa d p ocedu es a
#   d o he  c i e ia fo  Ho izo  Eu ope fu di g. I  pa icula ,  he Ge e al A exes
#   ou li e  he: – admissibili
#
# Metadata: {'question_type': 'complex', 'seed_document_id': 135, 'topic':
#   'content=\'"European Research Funding Program"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 7, \'prompt_tokens\': 1873, \'total_tokens\': 1880,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0\'
#   usage_metadata={\'input_tokens\': 1873, \'output_tokens\': 7,
#   \'total_tokens\': 1880, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# No matching row in df2 for question: For the MSCA Postdoctoral Fellowships 2024, is there a specific page limit for
#   Part B of the application form if the applicant is submitting a proposal in
#   the field of engineering?
# ================================================================================
# Question: Under what conditions must the host organization for the European Fellowship be
#   situated in a specific location, such as a MS / AC / Eu a om AC, according to
#   the application submission guidelines?
#
# Weak RAG:
#   Answer: The host organization for the European Fellowship must be situated in a Member
#   State (MS) or Associated Country (AC) of the European Union.
#   Judgment: False
#   Argument: The agent stated that the host organization must be situated in a Member State
#   or Associated Country of the European Union, but should have included 'Eu a om
#   AC' as well.
#
# Strong RAG:
#   Answer: The host organization for the European Fellowship must be situated in a Member
#   State (MS) or Associated Country (AC), according to the mobility rule stated
#   in the application submission guidelines. The researcher must not have resided
#   or carried out their main activity (work, studies, etc.) in the country of the
#   beneficiary (for European Postdoctoral Fellowships) for more than 12 months in
#   the 36 months immediately before the call deadline.
#   Judgment: False
#   Argument: The agent provided additional information about the mobility rule, which was not
#   asked for, and did not directly address the specific location requirement as
#   stated in the reference answer.
#
# Reference Answer: The host organization for the European Fellowship must be located in a MS / AC /
#   Eu a om AC.
#
# Reference Context: Document 69: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf page_number: 24
#   text: Eligibili y C i e ia The hos  o ga isa io (s) Be eficia y Associa ed Pa
#   e  • Hos  of  he Eu opea  Fellowship a d • Hos  of  he ou goi g phase of  he
#   Global  e u  phase of Global Fellowship Fellowship • Mus  be loca ed i  a MS /
#   AC / Eu a om AC • Seco dme  a d placeme  hos  • A y legal e i y wi hi  o  ou
#   side academia • A y legal e i y wi hi  o  ou side academia • Rec ui s  he pos
#   doc o al  esea che  • Loca ed a
#
# Metadata: {'question_type': 'distracting element', 'seed_document_id': 69,
#   'distracting_context': 'file_name: General annexes-diverse
#   regler_horizon-2023-2024_en.pdf\npage_number: 27\ntext: Ho izo  Eu ope - Wo k
#   p og amme 2023-2025\nGe e al A exes\nE — Docume s\nSubmissio \nAll p oposals
#   mus  be submi ed elec o ically via  he Fu de s & Te de s Po al elec o
#   ic\nsubmissio  sys em (accessible via  he  opic page i   he Sea ch Fu di g &
#   Te de s sec io ).\nPape  submissio s a e NOT possible.\nP oposals mus  be
#   comple e a d co ai  all pa s a d ma da o y a exes a d suppo i g\ndocume
#   s.\nThe applica io  fo m will have  wo pa s:\n– Pa  A ( o be filled i  di ec
#   ly o li e) co ai s admi is a ive i fo ma io  abou   he\napplica  o ga isa io s
#   (fu u e coo di a o  a d be eficia ies a d affilia ed e i ies),\n he summa ised
#   budge  fo   he p oposal a d call-specific ques io s;\n– Pa  B ( o be dow
#   loaded f om  he Po al submissio  sys em, comple ed a d  he \nassembled a d
#   e-uploaded as a PDF i   he sys em) co ai s  he  ech ical desc ip io \nof  he p
#   ojec .\nA exes a d suppo i g docume s will be di ec ly available i   he
#   submissio  sys em a d\nmus  be uploaded as PDF files (o  o he  fo ma s allowed
#   by  he sys em).\nP oposals should be desig ed  o s ay as close as possible  o
#   he awa d c i e ia (see A ex D\nabove). The applica io  fo m will help  o
#   achieve  his.\nWhe  submi i g  he p oposal,  he coo di a o  will have  o co fi
#   m  ha   hey have  he\nma da e  o ac  fo  all applica s. Mo eove ,  hey will
#   have  o co fi m  ha   he i fo ma io  i \n he applica io  is co ec  a d comple
#   e a d  ha  all pa icipa s comply wi h  he co di io s fo \n eceivi g EU fu di g
#   (especially eligibili y, fi a cial a d ope a io al capaci y, exclusio ,\ne
#   c.). P oposals  o  complyi g wi h  hese  equi eme s will be  ejec ed. Befo e
#   sig i g  he\ng a , each pa icipa  will have  o co fi m  his agai  by sig i g a
#   decla a io  of ho ou .\nFo  lump sum g a s p oposals,  he es ima ed budge  mus
#   be desc ibed i  a de ailed budge \n able. This will be used as a basis fo  jus
#   ifyi g a d/o  fixi g  he lump sum amou . As  he\nlump sum mus  be a  app oxima
#   io  of  he cos s ac ually i cu ed,  he cos s i cluded i   his\nde ailed budge
#   able mus  comply wi h  he basic eligibili y co di io s fo  EU ac ual cos \ng a
#   s (see AGA — A o a ed G a  Ag eeme , A icle 6). This is pa icula ly impo a  fo
#   \npu chases a d subco ac i g, which mus  e su e bes  value fo  mo ey (o , if
#   app op ia e,  he\nlowes  p ice) a d be f ee f om a y co flic s of i e es . If
#   he budge   able co ai s i eligible\ncos s,  he g a s may be  educed (eve  la e
#   o  du i g impleme a io  of  he p ojec  o  af e \n hey e d). Excep io ally,  he
#   Decisio  au ho isi g  he use of lump sum fu di g fo  a specific\nac io  migh
#   specify  ha  a de ailed budge   able is  o   equi ed.\nApplica s may be asked
#   a  a la e  s age fo  fu he  docume s (fo  legal e i y valida io ,\nfi a cial
#   capaci y check, ba k accou  valida io , e c.).\nPage 27 of 45', 'topic':
#   'content=\'"MSCA Postdoctoral Fellowships 2024"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 12, \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: Under the Horizon 2023-2024 program rules, what are some specific reasons an
#   applicant might be refused participation if they have failed to demonstrate
#   the necessary skills and experience at both the departmental and institutional
#   level?
#
# Weak RAG:
#   Answer: Applicants might be refused participation if they fail to demonstrate specific
#   measures to enhance career perspectives and employability both inside and
#   outside academia. Additionally, if they do not show expected contributions of
#   proposed skill development to their future career, they may also be refused
#   participation.
#   Judgment: False
#   Argument: The agent provided reasons related to career perspectives and employability, but
#   the reference answer specifies refusal reasons related to misrepresentation of
#   information and involvement in document preparation that breaches equality of
#   treatment.
#
# Strong RAG:
#   Answer: An applicant might be refused participation under the Horizon 2023-2024 program
#   rules if they fail to demonstrate necessary skills and experience, such as:
#   1. **Teaching and Mentoring Skills**: They should show capability in teaching
#   and mentoring students and doctoral candidates, emphasizing their development
#   in leadership and communication skills.  2. **Project Management Skills**: The
#   ability to manage projects, including project planning and organizing
#   conferences, is essential.  3. **Skills in International Environments**:
#   Applicants must demonstrate skills in working within international settings,
#   including communication and building networks.  4. **Entrepreneurial Skills
#   and Competencies**: They should possess entrepreneurial skills and
#   competencies.  5. **Handling Intellectual Property Rights (IPR)**:
#   Demonstrating skills in handling IPR, including training in patent law, is
#   necessary.  6. **Complementarity with Host Organization**: There should be
#   clear complementary expertise between the applicant’s profile, their
#   supervisor(s), and the host organization.   Failure to exhibit these
#   competencies at both the departmental and institutional levels could lead to
#   refusal of participation.
#   Judgment: False
#   Argument: The agent provided reasons related to skills and competencies, but the reference
#   answer specifies refusal due to misrepresentation of information or
#   involvement in document preparation that breaches equality of treatment.
#
# Reference Answer: Applicants will be refused if they have misrepresented the information required
#   as a condition for participating in the procedure or have failed to supply
#   that information; or were previously involved in the preparation of documents
#   used in the award procedure where this entails a breach of the principle of
#   equality of treatment, including distortion of competition, that cannot be
#   remedied otherwise.
#
# Reference Context: Document 154: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 22 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   − ba k up cy, wi di g up, affai s admi is e ed by  he cou s, a a geme  wi h c
#   edi o s, suspe ded busi ess ac ivi ies o  o he  simila  p ocedu es (i cludi g
#   p ocedu es fo  pe so s wi h u limi ed liabili y fo   he applica ’s deb s); −
#   hey a e i  b each of social secu i y o   ax obliga io s (i cludi g if do e by
#   pe so s wi h u limi ed liabi
#
# Metadata: {'question_type': 'distracting element', 'seed_document_id': 154,
#   'distracting_context': 'file_name:
#   240514_MSCA_PF_Info_Day_Overview-1.pdf\npage_number: 36\ntext: Hos  I s i u io
#   s\nWhy a e  hey  he bes  place  o u de ake  he p ojec ?\nDoes  he hos  have
#   he  ecessa y skills a d expe ie ce\n o help mee   he p ojec  objec ives ( esea
#   ch &  ai i g)?\nLook beyo d  he po e ial supe viso  – depa me al &\ni s i u io
#   al level ma e s as well\nHow will you be i eg a ed i o  he i s i u io ?\nThe i
#   s i u io   eeds  o be awa e of  he submissio !\nWo k closely wi h colleagues
#   o se  expec a io s a d avoid\nsu p ises (du i g p oposal developme  a d p ojec
#   \nimpleme a io )', 'topic': 'content=\'"European Research Funding Program"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 7, \'prompt_tokens\': 1873, \'total_tokens\': 1880,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0\'
#   usage_metadata={\'input_tokens\': 1873, \'output_tokens\': 7,
#   \'total_tokens\': 1880, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: In the context of the Horizon Europe program, what are the expected outcomes for
#   the execution stage of a PCP/PPI project, particularly if the procurement
#   procedure involves a two-stage submission process?
#
# Weak RAG:
#   Answer: In the context of the Horizon Europe program, the expected outcomes for the
#   execution stage of a PCP/PPI project, particularly if the procurement
#   procedure involves a two-stage submission process, include assessing the
#   results achieved by each bidder in the previous phase, giving a demonstration
#   to the granting authority of the tested solutions resulting from the PCP, and
#   ensuring that the procurement procedures are open to bidders from EU Member
#   States and countries with which the EU has agreements in the field of public
#   procurement under the conditions laid down in those agreements. Additionally,
#   if the specific call conditions require limited participation for security
#   reasons, participation in the PCP/PPI procedure must also be restricted to
#   bidders meeting this condition.
#   Judgment: False
#   Argument: The agent's answer focuses on procedural aspects and eligibility criteria, but
#   does not address the expected outcomes related to the implementation,
#   validation, and evaluation of solutions as described in the reference answer.
#
# Strong RAG:
#   Answer: In the context of the Horizon Europe program, the expected outcome of the
#   execution stage for a PCP/PPI project is the implementation of the procurement
#   procedure and the execution of the PCP/PPI contracts.
#   Judgment: False
#   Argument: The agent's answer is incomplete. It mentions the implementation of the
#   procurement procedure and execution of the contracts but omits details about
#   validating and comparing PCP solutions, and deploying and evaluating PPI
#   solutions in real-life conditions.
#
# Reference Answer: The expected outcome of the execution stage is the implementation of the
#   procurement procedure and of the PCP/PPI contracts. For PCP, this includes
#   validating and comparing the performance of the competing PCP solutions to
#   verify if they can be converted into permanent service. For PPI, this includes
#   deploying the innovative solutions and evaluating the results in real-life
#   operating conditions, with a duration that allows for appropriate evaluation
#   of the potential impact of these solutions if converted into permanent
#   service.
#
# Reference Context: Document 171: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 39 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   Fo  PPI execu ed by a g oup of p ocu e s,  he lead p ocu e  mus  coo di a e
#   he p epa a io  a d impleme a io  of o e joi  o  seve al coo di a ed public p
#   ocu eme s of i ova ive solu io s, based o  commo  specifica io s defi ed joi
#   ly by  he buye s’ g oup. Each PPI mus  focus o  o e co c e e  eed ide ified as
#   a commo  challe ge  ha   equi
#
# Metadata: {'question_type': 'distracting element', 'seed_document_id': 171,
#   'distracting_context': 'file_name: General annexes-diverse
#   regler_horizon-2023-2024_en.pdf\npage_number: 28\ntext: Ho izo  Eu ope - Wo k
#   p og amme 2023-2025\nGe e al A exes\nF — P ocedu e\nEvalua io  p ocedu e a d
#   a ki g\nCalls may be subjec   o ei he  a si gle-s age submissio  p ocedu e o
#   a  wo-s age\nsubmissio  p ocedu e. The evalua io  p ocedu e may be o ga ised i
#   o e (s a da d) o \nseve al s eps.\nI   he fi s  s age of a  wo-s age submissio
#   , applica s will be  eques ed  o submi  o ly a \nou li e applica io  (which
#   will be evalua ed agai s  o ly  wo awa d c i e ia: ‘Excelle ce’ a d\n‘Impac
#   ’). Successful applica s will be i vi ed  o submi  a full applica io  fo   he
#   seco d\ns age (which will be evalua ed agai s   he full se  of awa d c i e
#   ia).\nP oposals will be checked fo  fo mal  equi eme s (admissibili y a d
#   eligibili y) a d  he \nevalua ed (fo  each  opic sepa a ely) by a  evalua io
#   commi ee composed of i depe de \nex e al expe s fo  ope a io al capaci y a d
#   awa d c i e ia (see A exes C a d D above) a d\n he   a ked acco di g  o  hei
#   quali y sco e.\nFo  lump sum g a s p oposals, comme s o   he de ailed lump sum
#   budge   able will be\np ovided i   he Evalua io  Summa y Repo  o ly fo  p
#   oposals i vi ed  o g a  ag eeme \np epa a io  (o  placed i   he  ese ve lis )
# ...
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What is it according to this?
#
# Weak RAG:
#   Answer: The threshold is expected to be set at 8 to 8.5.
#   Judgment: False
#   Argument: The agent stated that the threshold is expected to be set at 8 to 8.5, but
#   should have said it is 3.
#
# Strong RAG:
#   Answer: According to the context, the threshold is expected to be normally set at 8 to
#   8.5.
#   Judgment: False
#   Argument: The agent stated that the threshold is expected to be normally set at 8 to 8.5,
#   but should have said it is 3.
#
# Reference Answer: The individual threshold score for evaluation criteria in full applications is
#   3.
#
# Reference Context: Document 158: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 26 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   by  he p ocu e s/e d-use s. The ma ufac u i g a d sale of  he i ova ive solu
#   io s a e pe fo med by  he supplie s of  he solu io s, which a e  o  be eficia
#   ies bu  subco ac o s. F amewo k - Cla i y a d pe i e ce - C edibili y of  he -
#   Capaci y a d  ole of Pa e ship of  he p ojec ’s ac io  pla  of  he FPA each pa
#   icipa , a d  he Ag eeme s o
#
# Metadata: {'question_type': 'conversational', 'seed_document_id': 158, 'topic':
#   'content=\'"European Research Funding Program"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 7, \'prompt_tokens\': 1873, \'total_tokens\': 1880,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0\'
#   usage_metadata={\'input_tokens\': 1873, \'output_tokens\': 7,
#   \'total_tokens\': 1880, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What is the purpose of this?
#
# Weak RAG:
#   Answer: The purpose of this is to outline the roles and responsibilities of
#   participating organizations and individuals in a project proposal. It also
#   includes details about research, technology development, collaboration, and
#   commitment to the project.
#   Judgment: False
#   Argument: The agent provided a generic answer about project proposals, which is incorrect.
#   The correct answer should have been about the EU Toolbox on 5G cybersecurity's
#   aim to assess cyber threats and security risks for 5G networks and develop
#   European capacities in 5G technologies.
#
# Strong RAG:
#   Answer: The purpose of this context is to provide guidance and instructions for
#   preparing application forms and letters of commitment related to proposals for
#   the MSCA Postdoctoral Fellowship under the call HE-MSCA-2024-PF. It includes
#   recommendations for the use of generative AI tools in proposal preparation,
#   the role and responsibilities of associated partners linked to beneficiaries,
#   the importance of addressing societal contributions and impacts, research data
#   management in line with FAIR principles, and ensuring the appropriateness and
#   accuracy of content, among other key points.
#   Judgment: False
#   Argument: The agent provided information unrelated to the EU Toolbox on 5G cybersecurity,
#   instead discussing application forms and letters of commitment for MSCA
#   Postdoctoral Fellowship proposals.
#
# Reference Answer: The EU Toolbox on 5G cybersecurity aims to jointly identify and assess cyber
#   threats and security risks for 5G networks, and it recommends adding country-
#   specific information to protect European communication networks. It also
#   emphasizes developing European capacities in 5G and post-5G technologies to
#   mitigate strategic risks and avoid the participation of high-risk supplier
#   entities in technology development.
#
# Reference Context: Document 139: file_name: General annexes-diverse regler_horizon-2023-2024_en.pdf
#   page_number: 7 text: Ho izo  Eu ope - Wo k p og amme 2023-2025 Ge e al A exes
#   be wee  Chi a a d  he EU o   he Joi  Roadmap fo   he fu u e of EU-Chi a coope
#   a io  i  scie ce,  ech ology, a d i ova io  Res ic io s fo   he p o ec io  of
#   Eu opea  commu ica io   e wo ks — The p o ec io  of Eu opea  commu ica io   e
#   wo ks has bee  ide ified as a  impo a  secu i y i e es  of  he U io  a d i s
#   Membe  S a es.10 I  li e wi h
#
# Metadata: {'question_type': 'conversational', 'seed_document_id': 139, 'topic':
#   'content=\'"European Research Funding Program"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 7, \'prompt_tokens\': 1873, \'total_tokens\': 1880,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7ff71476-8c50-4cf4-973e-8a0dbd482bf0-0\'
#   usage_metadata={\'input_tokens\': 1873, \'output_tokens\': 7,
#   \'total_tokens\': 1880, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What aspects should be addressed?
#
# Weak RAG:
#   Answer: The aspects that should be addressed include the role of participation in the
#   organization in the project, project management, communication, dissemination,
#   engagement, provision of research and technology, co-definition of research
#   and market needs, civil society representation, policy-making or regulation,
#   research performance, technology development, testing/validation of approaches
#   and ideas, prototyping and demonstration, IPR management, ethics information,
#   and additional ethics information.
#   Judgment: False
#   Argument: The agent provided a list of general aspects related to project participation
#   and management, but did not specifically address hosting arrangements and the
#   quality and capacity of participating organizations as required by the
#   reference answer.
#
# Strong RAG:
#   Answer: The aspects that should be addressed are:  1. Detailed discussion on engaging
#   the wider community through conferences, workshops, or other non-technical
#   activities, with evidence of the researcher's previous experience in such
#   activities. 2. A well-defined communication strategy for the wider audience,
#   providing sufficient information regarding the content and message to be
#   communicated to each different group and the number of communication events.
#   3. Tools to measure and analyze the impact of communication activities. 4.
#   Dissemination of the project results to the industry and application
#   community. 5. Intellectual property management and the way it will be shared
#   among researchers, the host, and the secondment institutions.
#   Judgment: False
#   Argument: The agent provided aspects related to communication, dissemination, and
#   intellectual property management, but should have addressed hosting
#   arrangements and the quality and capacity of participating organizations,
#   including infrastructure, logistics, and facilities.
#
# Reference Answer: At a minimum, the following aspects should be addressed: Hosting arrangements,
#   including integration in the team/institution(s) and support services
#   available to the researcher; Quality and capacity of the participating
#   organizations, including infrastructure, logistics, and facilities.
#
# Reference Context: Document 123: file_name: Ansökningsmallen med instruktioner.pdf page_number: 34
#   text: Call: HORIZON-MSCA-2024-PF-01: MSCA Pos doc o al Fellowships 2024 EU G a
#   s: Applica io  fo m (HE MSCA PF): V3.1 – 28.03.2024 - Eco omic/ ech ological:
#   e.g. b i gi g  ew p oduc s, se vices, busi ess p ocesses  o  he ma ke , i c
#   easi g efficie cy, dec easi g cos s, i c easi g p ofi s, co ibu i g  o s a da
#   ds’ se i g, e c. - Socie al: e.g. dec easi g CO2 emissio s, dec easi g
#   avoidable mo ali y, imp ovi g policies
#
# Metadata: {'question_type': 'conversational', 'seed_document_id': 123, 'topic':
#   'content=\'"MSCA Postdoctoral Fellowships 2024"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 12, \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What are some of these?
#
# Weak RAG:
#   Answer: Some of the identified risks and emergency plans related to methods and data
#   collection were well considered in the proposal. Additionally, efforts
#   assigned to work packages, including the timing and duration of different work
#   packages, were appropriate and credible within the research work. The
#   allocation of tasks and resources was also considered appropriate in the
#   proposal.
#   Judgment: False
#   Argument: The agent provided information about risks, emergency plans, and work packages,
#   which is unrelated to the open science practices mentioned in the reference
#   answer.
#
# Strong RAG:
#   Answer: Regular meetings between the researcher and the supervisor, regular data reports
#   for the host laboratory/institute, meetings with supervisors, reporting to the
#   EU, partnership agreements between the two host organizations, dissemination
#   and communication activities, involvement of citizens and civil society in the
#   co-creation of R&I agendas, providing open access to research outputs such as
#   publications, data, software, models, and algorithms.
#   Judgment: False
#   Argument: The agent included some correct elements like providing open access to research
#   outputs and involving citizens, but also mentioned irrelevant practices like
#   regular meetings and reporting to the EU, which are not specific to open
#   science practices.
#
# Reference Answer: Open science practices include early and open sharing of research (for example
#   through pre-registration, registered reports, pre-prints, or crowd-sourcing);
#   research output management; measures to ensure reproducibility of research
#   outputs; providing open access to research outputs (such as publications,
#   data, software, models, algorithms, and workflows); participation in open
#   peer-review; and involving all relevant knowledge actors including citizens,
#   civil society and end users in the co-creation of R&I agendas and contents
#   (such as citizen science).
#
# Reference Context: Document 19: file_name: MSCA_PF2024_handbook-1.pdf page_number: 20 text: MSCA
#   POSTDOCTORAL FELLOWSHIP HANDBOOK 2024 Ope  scie ce is a  app oach based o  ope
#   coope a ive wo k a d sys ema ic sha i g of k owledge a d  ools as ea ly a d
#   widely as possible i   he p ocess. Ope  scie ce p ac ices i clude ea ly a d
#   ope  sha i g of  esea ch (fo  example  h ough p e-  egis a io ,  egis e ed
#   epo s, p e-p i s, o  c owd-sou ci g);  esea ch ou pu  ma ageme ; measu es  o e
#   su e  ep oducibili y of  esea ch ou
#
# Metadata: {'question_type': 'conversational', 'seed_document_id': 19, 'topic':
#   'content=\'"MSCA Postdoctoral Fellowships 2024"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 12, \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
#
# ================================================================================
# Question: What is needed for these entities?
#
# Weak RAG:
#   Answer: Outcomes of the project's results by direct target groups.
#   Judgment: False
#   Argument: The agent's answer about outcomes of the project's results does not address the
#   requirement for host organizations, which is a letter of commitment.
#
# Strong RAG:
#   Answer: The context provided requires that any inter-relationship between the
#   participating organizations or individuals and other entities/persons (e.g.,
#   family ties, shared premises or facilities, joint ownership, financial
#   interests, overlapping staff or directors, etc.) must be declared in the
#   proposal.
#   Judgment: False
#   Argument: The agent provided information about declaring inter-relationships, but the
#   correct answer is that a letter of commitment is required for partner
#   organizations in a third country.
#
# Reference Answer: A letter of commitment is required for partner organizations in a third country
#   hosting the outgoing phase of a Global Fellowship.
#
# Reference Context: Document 83: file_name: 240514_MSCA_PF_Info_Day_Overview-1.pdf page_number: 38
#   text: Le e s of Commi me  A  equi eme  fo : ❖ pa e  o ga isa io s i  a  hi d
#   cou y hos i g  he ou goi g phase of a Global Fellowship ❖ The le e  mus  be
#   up- o-da e a d o  headed pape  ❖ I  should co fi m  eal a d ac ive pa icipa io
#   i   he p oposed ac io  ❖ Ge e al guideli es a e give : MSCA_PF2023_ha dbook_fi
#   al.pdf (msca- e .eu) ❖ Remembe   ha   hey ca   ake some  ime  o ge  sig ed
#   Failu e  o i clude a le e  of comm
#
# Metadata: {'question_type': 'conversational', 'seed_document_id': 83, 'topic':
#   'content=\'"MSCA Postdoctoral Fellowships 2024"\'
#   additional_kwargs={\'refusal\': None} response_metadata={\'token_usage\':
#   {\'completion_tokens\': 12, \'prompt_tokens\': 2177, \'total_tokens\': 2189,
#   \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0,
#   \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\':
#   0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}},
#   \'model_name\': \'gpt-4o-2024-08-06\', \'system_fingerprint\':
#   \'fp_703d4ff298\', \'finish_reason\': \'stop\', \'logprobs\': None}
#   id=\'run-7d3358ff-d8ce-454a-9360-0269ab8739dd-0\'
#   usage_metadata={\'input_tokens\': 2177, \'output_tokens\': 12,
#   \'total_tokens\': 2189, \'input_token_details\': {\'audio\': 0,
#   \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\':
#   0}}'}
# ================================================================================
